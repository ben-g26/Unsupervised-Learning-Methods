# %% [markdown]
# <a href="https://colab.research.google.com/github/ben-g26/Unsupervised-Learning-Methods/blob/main/Eddies_from_altimetry_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 2: Using GPSat to reconstruct the eddy signature

# %% [markdown]
# In Part 1 of "Finding Ocean Eddies using Satellite Altimetry", we explored the AVISO+ Mesoscale Eddy Trajectory Atlas (META3.2 DT) to identify a significant eddy within a region and timeframe of interest. After selecting a target eddy, we extracted its key parameters and retrieved Sentinel-3 altimetry data within a defined buffer zone around it.
#
# In Part 2 of this study, we will use GPSat to optimally interpolate the sea surface height anomaly (SSHA) derived from Sentinel-3 data in attempt to reconstruct our selected eddy.

# %% [markdown]
# ## Install and load GPSat and the required packages

# %%
! pip install gpflow
# Out:
# Requirement already satisfied: gpflow in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Requirement already satisfied: check-shapes>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gpflow) (1.1.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from gpflow) (1.3.1)
# Requirement already satisfied: multipledispatch>=0.6 in /usr/local/lib/python3.12/dist-packages (from gpflow) (1.0.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (from gpflow) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gpflow) (26.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gpflow) (1.16.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from gpflow) (75.2.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from gpflow) (0.9.0)
# Requirement already satisfied: tensorflow-probability>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-probability[tf]>=0.12.0->gpflow) (0.25.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from gpflow) (4.15.0)
# Requirement already satisfied: tensorflow>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from gpflow) (2.19.0)
# Requirement already satisfied: dropstackframe>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from check-shapes>=1.0.0->gpflow) (0.1.1)
# Requirement already satisfied: lark<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from check-shapes>=1.0.0->gpflow) (1.3.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (2.32.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (3.16.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.4.0->gpflow) (0.5.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (3.1.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (0.1.9)
# Requirement already satisfied: tf-keras>=2.16 in /usr/local/lib/python3.12/dist-packages (from tensorflow-probability[tf]>=0.12.0->gpflow) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.4.0->gpflow) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.4.0->gpflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.4.0->gpflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.4.0->gpflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.4.0->gpflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.4.0->gpflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.4.0->gpflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.4.0->gpflow) (3.1.6)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (25.4.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.4.0->gpflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.1.2)

# %%
# @title
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# TODO: allow for mounting of gdrive
# TODO: allow for checking out a branch

if IN_COLAB:

    import os
    import re

    # change to working directory
    work_dir = "/content"

    assert os.path.exists(work_dir), f"workspace directory: {work_dir} does not exist"
    os.chdir(work_dir)

    # clone repository
    # !git clone https://github.com/CPOMUCL/GPSat.git

    repo_dir = os.path.join(work_dir, "GPSat")

    print(f"changing directory to: {repo_dir}")
    os.chdir(repo_dir)
# Out:
# fatal: destination path 'GPSat' already exists and is not an empty directory.
# changing directory to: /content/GPSat

# %%
# @title
if IN_COLAB:
    # !pip install -r requirements.txt
# Out:
# Ignoring tensorflow: markers 'platform_system == "Darwin" and platform_machine == "x86_64"' don't match your environment
# Ignoring tensorflow-macos: markers 'platform_system == "Darwin" and platform_machine == "arm64"' don't match your environment
# Ignoring gpflow: markers 'platform_system == "Darwin" and platform_machine == "arm64"' don't match your environment
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: astropy>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (7.2.0)
# Requirement already satisfied: chardet>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (5.2.0)
# Collecting pandas==1.5.3 (from -r requirements.txt (line 7))
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# @title
if IN_COLAB:
    # !pip install -e .
# Out:
# Obtaining file:///content/GPSat
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: astropy>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from GPSat==0.0.1) (7.2.0)
# Requirement already satisfied: chardet>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from GPSat==0.0.1) (5.2.0)
# Collecting pandas==1.5.3 (from GPSat==0.0.1)
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# @title
# !pip install cartopy
# !pip install deprecated
# !pip install dataclasses_json
# !pip install global_land_mask
# !pip install netCDF4
# Out:
# Requirement already satisfied: cartopy in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (26.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (1.3.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated) (2.1.2)
# Requirement already satisfied: dataclasses_json in /usr/local/lib/python3.12/dist-packages (0.6.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses_json) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses_json) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.12/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses_json) (26.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses_json) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses_json) (4.15.0)
# Requirement already satisfied: global_land_mask in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (1.7.4)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2026.2.25)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from netCDF4) (1.26.4)

# %%
# @title
# Standard Library Imports
import importlib
import os
import re
import sys
from pathlib import Path

# Third-Party Library Imports
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import xarray as xr
from global_land_mask import globe
from pyproj import Proj, transform
from scipy.spatial import KDTree

# Local / GPSat Imports
import GPSat
import GPSat.plot_utils
import GPSat.utils
from GPSat import get_data_path, get_parent_path
from GPSat.config_dataclasses import DataConfig, ExpertLocsConfig, ModelConfig, PredictionLocsConfig
from GPSat.dataprepper import DataPrep
from GPSat.local_experts import LocalExpertOI, get_results_from_h5file
from GPSat.models.gpflow_models import GPflowGPRModel
from GPSat.models.sklearn_models import sklearnGPRModel
from GPSat.plot_utils import get_projection, plot_pcolormesh, plot_pcolormesh_from_results_data
from GPSat.postprocessing import glue_local_predictions_1d, glue_local_predictions_2d
from GPSat.utils import EASE2toWGS84_New, WGS84toEASE2_New, cprint, get_weighted_values, grid_2d_flatten

# %% [markdown]
# ## Set paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
week8_path = Path('/content/drive/MyDrive/AI_for_Earth_Observation/Week_8')

# %% [markdown]
# ## Load our selected eddy

# %%
#Load the selected eddy data
eddy_number = 716714
date = pd.to_datetime("2019-01-01").date()
#load the selected eddy
selected_eddy = gpd.read_file(week8_path /f"selected_eddy_{date}_{eddy_number}.gpkg", layer='row')

# %%
selected_eddy
# Out:
#    track_number       time  longitude   latitude  amplitude  effective_height  \
# 0        716714 2019-01-01  43.179535 -59.752373     0.0517              0.06
#
#    inner_height  effective_area          type  \
# 0          0.11    18620.588816  Anticyclonic
#
#                                             geometry
# 0  POLYGON ((43.12 -60.86, 43.38 -60.86, 43.48 -6...

# %%
#The eddy coords use the 0-360 longitude convention, let's change them to -180 to 180 for consistency with the EPSG:4326 projection

from shapely.geometry import Polygon

# Function to shift longitudes from 0-360 to -180 to 180
def shift_longitude(geometry):
    if geometry.geom_type == "Polygon":
        new_coords = [((lon - 360 if lon > 180 else lon), lat) for lon, lat in geometry.exterior.coords]
        return Polygon(new_coords)
    elif geometry.geom_type == "MultiPolygon":
        new_polygons = []
        for poly in geometry.geoms:
            new_coords = [((lon - 360 if lon > 180 else lon), lat) for lon, lat in poly.exterior.coords]
            new_polygons.append(Polygon(new_coords))
        return gpd.GeoSeries(new_polygons).unary_union  # Convert list back to MultiPolygon
    return geometry

selected_eddy["geometry"] = selected_eddy["geometry"].apply(shift_longitude)
selected_eddy = selected_eddy.set_crs('EPSG:4326')

# %%
#plot the selected eddy location
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.SouthPolarStereo()})
ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.COASTLINE)
ax.add_geometries([selected_eddy.geometry.iloc[0]], crs=ccrs.PlateCarree(), facecolor='red', edgecolor='red')
eddy_proxy = mlines.Line2D([], [], color='red', linewidth=4, alpha=0.8, label="Selected known eddy")
ax.legend(handles=[eddy_proxy], loc='lower left')
plt.show()

# %% [markdown]
# ## Load the Sentinel-3 altimetry data and compute SSHA

# %% [markdown]
# Sea Surface Height Anomaly (SSHA) represents the deviation of the instantaneous sea surface height (SSH) from a long-term mean sea surface (MSS). It provides insights into ocean circulation, mesoscale eddies, and sea level variability, making it a key parameter in altimetry-based ocean studies.
#
# SSHA is calculated as:
#
# $$
# \text{SSHA} = \text{SSH} - \text{MSS}
# $$
#
# where:
#
# SSH (Sea Surface Height) is the instantaneous height of the sea surface measured by the satellite altimeter.
# MSS (Mean Sea Surface) represents the long-term average sea surface height, derived from multi-year satellite observations.
# SSHA is particularly useful for detecting dynamic ocean features, such as eddies, currents, and tides, as it removes the static component of the sea surface height, revealing short-term variability.
#
# The Sentinel-3 product we will be using in this practical does not include SSH derived from the ideal opean ocean retracker (SAMOSA). We therefore need to compute it from the SAMOSA-retracked range to the water surface, including correcting for geophysical effects contaminating our signal.
#
# SSHA is therefore calculated as:
#
# ***SSH = H - R - C***
#
# $$
# \text{SSH} = \text{H} - \text{R} - \text{C}
# $$
#
# where:
#
# H = Satellite Altitude
#
# R = Ku-band retracked range to water
#
# C = Geophysical Corrections, which include:
# Ionospheric correction, dry tropospheric correction,
# wet tropospheric corrections, sea state bias correction,
# tidal corrections, inverted barometer correction high-frequency sea surface fluctuation correction

# %%
# @title
def add_sea_surface_height_and_anomaly(sral_ds):
    """
    Calculate the sea surface height anomaly from a Sentinel-3 SRAL dataset.
    Based on the L2 WAT definition:
    SSHA = altitude of satellite (alt_20_ku) - Ku band corrected ocean altimeter range (range_ocean_20_ku)
    - filtered altimeter ionospheric correction on Ku band (iono_cor_alt_filtered_01_ku)
    - model dry tropospheric correction (mod_dry_tropo_cor_zero_altitude_01)
    - radiometer wet tropospheric correction (rad_wet_tropo_cor_01_ku)
    - sea state bias correction in Ku band (sea_state_bias_01_ku)
    - solid earth tide height (solid_earth_tide_01)
    - geocentric ocean tide height solution 2 = FES (ocean_tide_sol2_01)
    - geocentric pole tide height (pole_tide_01)
    - inverted barometer height correction (inv_bar_cor_01)
    - high frequency fluctuations of the sea surface topography (hf_fluct_cor_01 for NTC/STC off line products only)
    - mean sea surface (mean_sea_surf_sol2_20_ku)"

    Parameters:
    sral_ds (xarray.Dataset): The Sentinel-3 SRAL dataset.
    Returns:
    The Sentinel-3 SRAL dataset with the calculated sea surface height and sea surface height anomaly.
    """

    #Before we can calculate the sea surface height anomaly (SSHA), we need to interpolate the 1Hz corrections to the 20Hz data
    mod_dry_tropo_cor_zero_altitude_20_ku = sral_ds.mod_dry_tropo_cor_zero_altitude_01.interp(time_01=sral_ds.time_20_ku)
    iono_cor_alt_filtered_20_ku = sral_ds.iono_cor_alt_filtered_01_ku.interp(time_01=sral_ds.time_20_ku)
    rad_wet_tropo_cor_20_ku = sral_ds.rad_wet_tropo_cor_01_ku.interp(time_01=sral_ds.time_20_ku)
    sea_state_bias_20_ku = sral_ds.sea_state_bias_01_ku.interp(time_01=sral_ds.time_20_ku)
    solid_earth_tide_20_ku = sral_ds.solid_earth_tide_01.interp(time_01=sral_ds.time_20_ku)
    ocean_tide_sol2_20_ku = sral_ds.ocean_tide_sol2_01.interp(time_01=sral_ds.time_20_ku)
    pole_tide_20_ku = sral_ds.pole_tide_01.interp(time_01=sral_ds.time_20_ku)
    inv_bar_cor_20_ku = sral_ds.inv_bar_cor_01.interp(time_01=sral_ds.time_20_ku)
    hf_fluct_cor_20_ku = sral_ds.hf_fluct_cor_01.interp(time_01=sral_ds.time_20_ku)

    # Calculate the sea surface height
    ssh = sral_ds.alt_20_ku - sral_ds.range_water_20_ku - iono_cor_alt_filtered_20_ku - mod_dry_tropo_cor_zero_altitude_20_ku - rad_wet_tropo_cor_20_ku - sea_state_bias_20_ku - solid_earth_tide_20_ku - ocean_tide_sol2_20_ku - pole_tide_20_ku - inv_bar_cor_20_ku - hf_fluct_cor_20_ku

    ssh.attrs = {
        "long_name": "Sea Surface Height",
        "units": "m",
        "standard_name": "sea_surface_height_above_sea_leved",
        "comment": "Calculated as SSH = altitude of satellite (alt_20_ku) - Ku band corrected ocean altimeter range (range_ocean_20_ku) - filtered altimeter ionospheric correction on Ku band (iono_cor_alt_filtered_01_ku) - model dry tropospheric correction (mod_dry_tropo_cor_zero_altitude_01) - radiometer wet tropospheric correction (rad_wet_tropo_cor_01_ku) - sea state bias correction in Ku band (sea_state_bias_01_ku) - solid earth tide height (solid_earth_tide_01) - geocentric ocean tide height solution 2 = FES (ocean_tide_sol2_01) - geocentric pole tide height (pole_tide_01) - inverted barometer height correction (inv_bar_cor_01) - high frequency fluctuations of the sea surface topography (hf_fluct_cor_01 for NTC/STC off line products only)"
    }

    sral_ds['ssh_20_ku'] = ssh

    # Calculate the sea surface height anomaly
    ssha = ssh - sral_ds.mean_sea_surf_sol2_20_ku

    ssha.attrs = {
        "long_name": "Sea Surface Height Anomaly",
        "units": "m",
        "standard_name": "sea_surface_height_above_sea_leved",
        "comment": "Calculated as SSHA = ssha - mean sea surface (mean_sea_surf_sol2_20_ku)"
    }

    sral_ds['ssha_20_ku'] = ssha

    return sral_ds

# %% [markdown]
# Let's iterate through the Sentinel-3 SRAL data we downloaded in part 1 of this practical, load it, calculate the SSH and SSHA, and do some filtering to reduce the memory load

# %%
import shutil
import xarray as xr

eddy_sral_dir = week8_path / 'S3_SRAL' / f"Eddy_num_{eddy_number}"

sral_filepaths = list(eddy_sral_dir.glob('**/*enhanced_measurement.nc'))

vars_of_interest = [
    'ssha_20_ku', 'ssh_20_ku', 'range_water_20_ku', 'alt_20_ku',
    'sea_ice_ssha_20_ku', 'int_sea_ice_ssha_20_ku',
    'mean_sea_surf_sol2_20_ku', 'sea_ice_sea_surf_20_ku',
    'surf_type_class_20_ku', 'sea_ice_concentration_20_ku',
    'freeboard_20_ku', 'dist_coast_20_ku'
]

sral_datasets = []

for i, sral_filepath in enumerate(sral_filepaths):
    print(f"Opening {sral_filepath}")

    local_path = f"/content/tmp_sral_{i}.nc"
    shutil.copy2(sral_filepath, local_path)

    ds = xr.open_dataset(local_path, engine="h5netcdf")
    ds = add_sea_surface_height_and_anomaly(ds)
    ds = ds[vars_of_interest]
    # ds = ds.where(ds.lat_20_ku <= -75, drop=True)
    # ds = ds.where(ds.lat_20_ku >= 80, drop=True)
    ds = ds.where(ds.dist_coast_20_ku >= 25e3, drop=True)

    sral_datasets.append(ds.load())   # load into memory before next temp file reuse
    ds.close()

sral_ds = xr.concat(sral_datasets, dim='time_20_ku')

del sral_datasets, ds
# Out:
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181225T054203_20181225T055837_20230717T013226_0993_020_119______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181225T062113_20181225T063814_20230522T170046_1021_039_262______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181225T191018_20181225T192832_20230717T013230_1093_020_127______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181225T195021_20181225T200821_20230522T172108_1079_039_270______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181226T055518_20181226T061204_20230522T175239_1006_039_276______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181226T192357_20181226T194158_20230522T182849_1080_039_284______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181226T202556_20181226T204350_20230717T030459_1074_020_142______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181227T052909_20181227T054546_20230522T184504_0997_039_290______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181227T063021_20181227T064726_20230717T033651_1024_020_148______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181227T195937_20181227T201729_20230717T052504_1071_020_156______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181228T060418_20181228T062115_20230717T050110_1016_020_162______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181228T064340_20181228T070050_20230522T202822_1030_039_305______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181228T193313_20181228T195116_20230717T054743_1082_020_170______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181228T201301_20181228T203048_20230522T210139_1066_039_313______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181229T053818_20181229T055452_20230717T061231_0993_020_176______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181229T061730_20181229T063430_20230522T205752_1020_039_319______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181229T194635_20181229T200437_20230522T215557_1081_039_327______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181230T055136_20181230T060817_20230522T221651_1000_039_333______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181230T192008_20181230T193811_20230523T202731_1082_039_341______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181230T202211_20181230T204001_20230717T084401_1069_020_199______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20181231T052525_20181231T054204_20230522T231550_0999_039_347______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181231T062637_20181231T064341_20230717T100910_1023_020_205______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20181231T195550_20181231T201345_20230717T100640_1075_020_213______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190101T060037_20190101T061731_20230331T153406_1013_020_219______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190101T063956_20190101T065704_20230523T005811_1028_039_362______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190101T192927_20190101T194729_20230331T163001_1081_020_227______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190101T200917_20190101T202704_20230523T020144_1067_039_370______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190102T053434_20190102T055109_20230331T165838_0995_020_233______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190102T061346_20190102T063047_20230523T020233_1020_039_376______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190102T194250_20190102T200053_20230523T030306_1082_039_384______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190103T054754_20190103T060430_20230523T033221_0996_040_005______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190103T191618_20190103T193424_20230523T034457_1085_040_013______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190103T201826_20190103T203614_20230331T193314_1067_020_256______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190104T062253_20190104T063955_20230331T230435_1021_020_262______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190104T195203_20190104T201001_20230331T210334_1078_020_270______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190104T203147_20190104T204953_20230523T045337_1085_040_028______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190105T055657_20190105T061345_20230331T214234_1008_020_276______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190105T063612_20190105T065319_20230523T052906_1026_040_034______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190105T192540_20190105T194341_20230331T223010_1080_020_284______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190105T200532_20190105T202320_20230523T055822_1068_040_042______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190106T053049_20190106T054726_20230331T225449_0996_020_290______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190106T061005_20190106T062704_20230523T060355_1019_040_048______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190106T193905_20190106T195709_20230523T065748_1083_040_056______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190107T054410_20190107T060044_20230523T070735_0994_040_062______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190107T064520_20190107T070232_20230401T004122_1032_020_305______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190107T191228_20190107T193039_20230523T082810_1090_040_070______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190107T201442_20190107T203228_20230401T012452_1066_020_313______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190108T061909_20190108T063610_20230401T020249_1021_020_319______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3B_SR_2_LAN_SI_20190108T194816_20190108T200617_20230401T025950_1081_020_327______LN3_R_NT_005.SEN3/enhanced_measurement.nc
# Opening /content/drive/MyDrive/AI_for_Earth_Observation/Week_8/S3_SRAL/Eddy_num_716714/S3A_SR_2_LAN_SI_20190108T202803_20190108T204601_20230523T124211_1077_040_085______LN3_R_NT_005.SEN3/enhanced_measurement.nc

# %% [markdown]
# Now we can define our training window for GPSat and ensure that the S3 data we have only covers the relevant dates. We will also filter out any obvious SSHA outliers (> 1m in amplitude)

# %%
training_window = pd.Timedelta(days=7)
#Crop the sral data to the date ± training window
sral_ds = sral_ds.where((sral_ds.time_20_ku.dt.date >= date - training_window) & (sral_ds.time_20_ku.dt.date <= date + training_window), drop=True)

#set to nan any sshas > 1m
sral_ds['ssha_20_ku'] = sral_ds['ssha_20_ku'].where(((sral_ds['ssha_20_ku'] <= 1) & (sral_ds['ssha_20_ku'] >= -1)), np.nan)

# %% [markdown]
# Plot some of the key variables relevant to this practical. Note that the dataset also includes sea_ice_ssha_20_ku and int_sea_ice_20_ku, which represent the sea surface height anomaly (SSHA) and interpolated SSHA over sea ice, respectively. These variables are derived using a specialised retracking algorithm for the sea ice environment. However, in this study, we have chosen to use the SAMOSA retracker and compute SSHA ourselves, as SAMOSA is targeted toward open ocean applications, likely providing more accurate sea level estimates in non-ice-covered regions.

# %%
#Plot each of the variables of interest in the general vicinity of the eddy
vars_to_plot = ['sea_ice_concentration_20_ku', 'mean_sea_surf_sol2_20_ku', 'ssh_20_ku', 'ssha_20_ku', 'sea_ice_ssha_20_ku', 'int_sea_ice_ssha_20_ku', 'sea_ice_sea_surf_20_ku']

# %matplotlib inline
fig, axs = plt.subplots(3, 3, figsize=(18, 15), subplot_kw={'projection': ccrs.SouthPolarStereo()})
axs = axs.flatten()
eddy_proxy = mlines.Line2D([], [], color='black', linewidth=2, linestyle='--', alpha=0.8, label="Selected known eddy")
for i, var in enumerate(vars_to_plot):
    ax = axs[i]
    ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
    ax.coastlines()
    ax.add_feature(cfeature.LAND, color='lightgray')
    ax.gridlines(alpha=0.5)
    if 'ssha' in var:
        sm = ax.scatter(sral_ds['lon_20_ku'], sral_ds['lat_20_ku'], c=sral_ds[var], cmap='coolwarm', transform=ccrs.PlateCarree(), s=1, vmin=-0.5, vmax=0.5)
    else:
        sm = ax.scatter(sral_ds['lon_20_ku'], sral_ds['lat_20_ku'], c=sral_ds[var], cmap='jet', transform=ccrs.PlateCarree(), s=1)
    cbar_label = sral_ds[var].long_name.split(': 20 Hz Ku band')[0]
    if 'units' in sral_ds[var].attrs:
        cbar_label += f" ({sral_ds[var].units})"
    fig.colorbar(sm, ax=ax, label=cbar_label)
    ax.set_title(var)

    #add the polygon of the selected eddy
    ax.add_geometries(
        [selected_eddy.iloc[0]['geometry']], crs=ccrs.PlateCarree(),
        facecolor="none", edgecolor="black", linewidth=1, linestyle='--', alpha=0.8,
    )
    ax.legend(handles=[eddy_proxy], loc='lower left')
#turn off any unused axes
for ax in axs[len(vars_to_plot):]:
    ax.axis('off')
plt.tight_layout()

# %% [markdown]
# ## Optimally interpolate SSHA

# %% [markdown]
# ### Format the dataset

# %%
#convert sral_ds to a pandas dataframe
sral_df = (sral_ds
           .to_dataframe()
           .reset_index())

#To make it simpler to retieve this eddy without worrying about ice-floe-contaminated data, we will just take points where the sea ice concentration is zero.
#We are therefore negleting any SSH measurements coming from leads in the nearby icepack.
sral_df = sral_df[sral_df['sea_ice_concentration_20_ku'] == 0]

sral_df.head()
# Out:
#                      time_20_ku  ssha_20_ku  ssh_20_ku  range_water_20_ku  \
# 0 2018-12-25 05:42:03.039928704    0.053733  37.473033        825146.1306
# 1 2018-12-25 05:42:03.090571136    0.144967  37.557667        825147.1173
# 2 2018-12-25 05:42:03.141213952    0.006501  37.412301        825148.3340
# 3 2018-12-25 05:42:03.191856384    0.010035  37.408835        825149.4087
# 4 2018-12-25 05:42:03.242499072    0.071069  37.463069        825150.4256
#
#      alt_20_ku  sea_ice_ssha_20_ku  int_sea_ice_ssha_20_ku  \
# 0  825181.2529                 NaN                     NaN
# 1  825182.3247                 NaN                     NaN
# 2  825183.3965                 NaN                     NaN
# 3  825184.4682                 NaN                     NaN
# 4  825185.5398                 NaN                     NaN
#
#    mean_sea_surf_sol2_20_ku  sea_ice_sea_surf_20_ku  surf_type_class_20_ku  \
# 0                   37.4193                     NaN                    0.0
# 1                   37.4127                     NaN                    0.0
# 2                   37.4058                     NaN                    0.0
# 3                   37.3988                     NaN                    0.0
# 4                   37.3920                     NaN                    0.0
#
#    sea_ice_concentration_20_ku  freeboard_20_ku  dist_coast_20_ku  lat_20_ku  \
# 0                          0.0              NaN         1073710.0 -56.122313
# 1                          0.0              NaN         1074027.0 -56.125200
# 2                          0.0              NaN         1074348.0 -56.128086
# 3                          0.0              NaN         1074672.0 -56.130972
# 4                          0.0              NaN         1075000.0 -56.133858
#
#    lon_20_ku
# 0  51.449729
# 1  51.448079
# 2  51.446429
# 3  51.444779
# 4  51.443128

# %%
# Format the dataframe to the convention used for the GPSat package
sral_df['t'] = sral_df['time_20_ku'].values.astype("datetime64[D]").astype(float)
sral_df['x'], sral_df['y'] = WGS84toEASE2_New(sral_df['lon_20_ku'].values, sral_df['lat_20_ku'].values, lat_0=-90)
sral_df
# Out:
# /tmp/ipykernel_99806/1550514514.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) WGS84toEASE2_New. (This function will be removed in future versions. Use `WGS84toEASE2` instead.)
#   sral_df['x'], sral_df['y'] = WGS84toEASE2_New(sral_df['lon_20_ku'].values, sral_df['lat_20_ku'].values, lat_0=-90)
#                           time_20_ku  ssha_20_ku  ssh_20_ku  \
# 0      2018-12-25 05:42:03.039928704    0.053733  37.473033
# 1      2018-12-25 05:42:03.090571136    0.144967  37.557667
# 2      2018-12-25 05:42:03.141213952    0.006501  37.412301
# 3      2018-12-25 05:42:03.191856384    0.010035  37.408835
# 4      2018-12-25 05:42:03.242499072    0.071069  37.463069
# ...                              ...         ...        ...
# 472458 2019-01-08 20:46:00.469622400    0.144765  34.482965
# 472459 2019-01-08 20:46:00.520188544    0.109740  34.448440
# 472460 2019-01-08 20:46:00.570754816    0.150415  34.489715
# 472461 2019-01-08 20:46:00.621320960    0.180989  34.521189
# 472462 2019-01-08 20:46:00.671900032    0.078764  34.420364
#
#         range_water_20_ku    alt_20_ku  sea_ice_ssha_20_ku  \
# 0             825146.1306  825181.2529                 NaN
# 1             825147.1173  825182.3247                 NaN
# 2             825148.3340  825183.3965                 NaN
# 3             825149.4087  825184.4682                 NaN
# 4             825150.4256  825185.5398                 NaN
# ...                   ...          ...                 ...
# 472458        824249.3018  824281.3650                 NaN
# 472459        824248.2212  824280.2499                 NaN
# 472460        824247.0647  824279.1347                 NaN
# 472461        824245.9181  824278.0196                 NaN
# 472462        824244.9033  824276.9040                 NaN
#
#         int_sea_ice_ssha_20_ku  mean_sea_surf_sol2_20_ku  \
# 0                          NaN                   37.4193
# 1                          NaN                   37.4127
# 2                          NaN                   37.4058
# 3                          NaN                   37.3988
# 4                          NaN                   37.3920
# ...                        ...                       ...
# 472458                     NaN                   34.3382
# 472459                     NaN                   34.3387
# 472460                     NaN                   34.3393
# 472461                     NaN                   34.3402
# 472462                     NaN                   34.3416
#
#         sea_ice_sea_surf_20_ku  surf_type_class_20_ku  \
# 0                          NaN                    0.0
# 1                          NaN                    0.0
# 2                          NaN                    0.0
# 3                          NaN                    0.0
# 4                          NaN                    0.0
# ...                        ...                    ...
# 472458                     NaN                    0.0
# 472459                     NaN                    0.0
# 472460                     NaN                    0.0
# 472461                     NaN                    0.0
# 472462                     NaN                    0.0
#
#         sea_ice_concentration_20_ku  freeboard_20_ku  dist_coast_20_ku  \
# 0                               0.0              NaN         1073710.0
# 1                               0.0              NaN         1074027.0
# 2                               0.0              NaN         1074348.0
# 3                               0.0              NaN         1074672.0
# 4                               0.0              NaN         1075000.0
# ...                             ...              ...               ...
# 472458                          0.0              NaN          947291.0
# 472459                          0.0              NaN          947086.0
# 472460                          0.0              NaN          946880.0
# 472461                          0.0              NaN          946670.0
# 472462                          0.0              NaN          946457.0
#
#         lat_20_ku  lon_20_ku        t             x             y
# 0      -56.122313  51.449729  17890.0  2.913207e+06  2.321445e+06
# 1      -56.125200  51.448079  17890.0  2.912899e+06  2.321338e+06
# 2      -56.128086  51.446429  17890.0  2.912592e+06  2.321230e+06
# 3      -56.130972  51.444779  17890.0  2.912285e+06  2.321122e+06
# 4      -56.133858  51.443128  17890.0  2.911978e+06  2.321015e+06
# ...           ...        ...      ...           ...           ...
# 472458 -54.234036  30.611306  17904.0  1.998972e+06  3.378555e+06
# 472459 -54.231143  30.609787  17904.0  1.999038e+06  3.378872e+06
# 472460 -54.228250  30.608269  17904.0  1.999105e+06  3.379189e+06
# 472461 -54.225356  30.606751  17904.0  1.999171e+06  3.379505e+06
# 472462 -54.222462  30.605233  17904.0  1.999238e+06  3.379822e+06
#
# [349337 rows x 18 columns]

# %% [markdown]
# ### Define a region of interest

# %%
# We need to define some grids, one for our expert locations and one for our prediction locations
# To help us create a grid in the relevant location and coordinate system, we'll start by making a buffer zone around the eddy and obtain its bounds
buffer = 200e3 #m
buffered_eddy = selected_eddy['geometry'].to_crs('EPSG:6932').iloc[0].buffer(buffer) #note that we must change the polygon crs to get a buffer in metres
minx, miny, maxx, maxy = buffered_eddy.bounds
print(minx, miny, maxx, maxy)
selected_eddy = selected_eddy.to_crs('EPSG:4326')

#plot the eddy, buffer and the bounds
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': ccrs.SouthPolarStereo()})
ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
ax.add_geometries([selected_eddy.iloc[0].geometry], crs=ccrs.PlateCarree(), facecolor='red', edgecolor='red')
ax.add_geometries([buffered_eddy], crs=ccrs.epsg(6932), facecolor='none', edgecolor='red', linewidth=2, linestyle='--', alpha=0.8)
buffer_boundary = ax.plot([minx, maxx, maxx, minx, minx], [miny, miny, maxy, maxy, miny], transform=ccrs.epsg(6932), color='black', linestyle='--', linewidth=2, label='Grid bounds')
ax.coastlines()
ax.gridlines(alpha=0.5)
eddy_proxy = mlines.Line2D([], [], color='red', linewidth=4, alpha=0.8, label="Selected known eddy")
buffer_proxy = mlines.Line2D([], [], color='red', linewidth=2, linestyle='--', alpha=0.8, label=f"{int(buffer/1e3)} km Buffer zone")
ax.legend(handles=[eddy_proxy, buffer_proxy, buffer_boundary[0]], loc='lower left')
plt.show()
# Out:
# 1999052.2702732556 2138319.262424667 2570834.4481193405 2736215.618001745

# %% [markdown]
# ### Define local experts

# %%
#Make a grid of expert locations using the bounds
expert_grid_res = 25e3
bounds = 0e3
grid_xcs = np.arange(minx + bounds, maxx+expert_grid_res/2 - bounds, expert_grid_res) #remember that the start is included and the stop is not
grid_ycs = np.arange(miny + bounds, maxy+expert_grid_res/2 - bounds, expert_grid_res)
grid_xcs_2d, grid_ycs_2d = np.meshgrid(grid_xcs, grid_ycs)
expert_locs = pd.DataFrame({'x': grid_xcs_2d.flatten(), 'y': grid_ycs_2d.flatten()})
# Add lon and lat
expert_locs['lon'], expert_locs['lat'] = EASE2toWGS84_New(expert_locs['x'], expert_locs['y'], lat_0=-90)
expert_locs['t'] = np.floor(sral_df['t'].mean())
# Identify if a position is in the ocean (water) or not
expert_locs["is_in_ocean"] = globe.is_ocean(expert_locs['lat'], expert_locs['lon'])
# keep only prediction locations in ocean
expert_locs = expert_locs.loc[expert_locs["is_in_ocean"]]
print(f'Number of expert locations: {len(expert_locs)}')
print("Local expert locations:")
expert_locs.head()
# Out:
# Number of expert locations: 600
# Local expert locations:
# /tmp/ipykernel_99806/745745468.py:9: DeprecationWarning: Call to deprecated function (or staticmethod) EASE2toWGS84_New. (This function will be removed in future versions. Use `EASE2toWGS84` instead.)
#   expert_locs['lon'], expert_locs['lat'] = EASE2toWGS84_New(expert_locs['x'], expert_locs['y'], lat_0=-90)
#               x             y        lon        lat        t  is_in_ocean
# 0  1.999052e+06  2.138319e+06  43.072110 -63.540143  17897.0         True
# 1  2.024052e+06  2.138319e+06  43.427490 -63.382258  17897.0         True
# 2  2.049052e+06  2.138319e+06  43.778745 -63.223286  17897.0         True
# 3  2.074052e+06  2.138319e+06  44.125922 -63.063243  17897.0         True
# 4  2.099052e+06  2.138319e+06  44.469065 -62.902145  17897.0         True

# %%
# Plot the eddy, buffer and the bounds
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': ccrs.SouthPolarStereo()})
ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
ax.add_geometries(selected_eddy.geometry, crs=ccrs.PlateCarree(), facecolor='red', edgecolor='red', alpha=0.4)
ax.add_geometries([buffered_eddy], crs=ccrs.epsg(6932), facecolor='none', edgecolor='red', linewidth=2, linestyle='--', alpha=0.8)
elocs = ax.scatter(expert_locs['x'], expert_locs['y'], transform=ccrs.epsg(6932), color='black', s=10, label='Expert locations')
ax.coastlines()
ax.gridlines(alpha=0.5)
eddy_proxy = mlines.Line2D([], [], color='red', linewidth=4, alpha=0.8, label="Selected known eddy")
buffer_proxy = mlines.Line2D([], [], color='red', linewidth=2, linestyle='--', alpha=0.8, label=f"{int(buffer/1e3)} km Buffer zone")
ax.legend(handles=[eddy_proxy, buffer_proxy, elocs], loc='lower left')
plt.show()

# %% [markdown]
# ### Define prediction locations

# %%
#Define a grid for the prediction locations
pred_grid_res = 5e3
pred_grid_xcs = np.arange(minx+pred_grid_res, maxx+pred_grid_res/2, pred_grid_res) #remember that the start is included and the stop is not
pred_grid_ycs = np.arange(miny+pred_grid_res, maxy+pred_grid_res/2, pred_grid_res)
pred_grid_xcs_2d, pred_grid_ycs_2d = np.meshgrid(pred_grid_xcs, pred_grid_ycs)
pred_locs = pd.DataFrame({'x': pred_grid_xcs_2d.flatten(), 'y': pred_grid_ycs_2d.flatten()})
# Add lon and lat columns
pred_locs['lon'], pred_locs['lat'] = EASE2toWGS84_New(pred_locs['x'].values, pred_locs['y'].values, lat_0=-90)
# Out:
# /tmp/ipykernel_99806/2841576273.py:8: DeprecationWarning: Call to deprecated function (or staticmethod) EASE2toWGS84_New. (This function will be removed in future versions. Use `EASE2toWGS84` instead.)
#   pred_locs['lon'], pred_locs['lat'] = EASE2toWGS84_New(pred_locs['x'].values, pred_locs['y'].values, lat_0=-90)

# %% [markdown]
# ### Bin observations (to reduce GPSat runtime)

# %% [markdown]
# To reduce the number of input data points and ultimately speed up getting some results, we will bin our observations. We will perform drop-in-a-bucket resampling to do this, whereby we average the data that falls within each bin (grid cell)

# %%
#Let us use the grid coordinates that we defined earlier for our prediction locations and use a KDTree to help bin the S3 data within each grid cell
gridded_obvs_dfs = []

for date_val, date_df in sral_df.groupby('t'):
  date_df = date_df.copy()
  gridded_observations = pred_locs
  #get the nearest grid cell to each observation
  tree = KDTree(np.vstack([gridded_observations['x'].values, gridded_observations['y'].values]).T)
  distances, indices = tree.query(np.vstack([date_df['x'].values, date_df['y'].values]).T, k=1)
  #nan where dist > max dist
  max_dist = 2.5e3
  indices[distances > max_dist] = -9999
  #get the mean of the observations in each grid cell
  date_df['nearest_grid_cell_index'] = indices
  date_df = date_df.groupby('nearest_grid_cell_index').mean()
  #drop x and y from the averaged date_df as we don't want the mean coords for the grid cell data- we will obtain the actual grid cell x and y when we merge the two datasets
  date_df = date_df.drop(columns=['x', 'y'])
  #merge the binned date_df with the gridded_observations dataframe
  gridded_observations = gridded_observations.merge(date_df, left_index=True, right_index=True, how='left')
  #drop rows with nan ssha values
  ssha_var = 'ssha_20_ku'
  # ssha_var = 'sea_ice_ssha_20_ku'
  gridded_observations = gridded_observations.dropna(subset=[ssha_var])
  #add the t column
  gridded_observations['t'] = date_val
  gridded_obvs_dfs.append(gridded_observations)
  del date_df, gridded_observations, tree, distances, indices

gridded_obvs_df = pd.concat(gridded_obvs_dfs)
gridded_obvs_df = gridded_obvs_df.reset_index(drop=True)

del gridded_obvs_dfs
gridded_obvs_df.head()
print(f'We have reduced the number of observations from {len(sral_df)} to {len(gridded_obvs_df)}')

# Plot the eddy, buffer and the bounds
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': ccrs.SouthPolarStereo()})
ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
ax.add_geometries(selected_eddy.geometry, crs=ccrs.PlateCarree(), facecolor='red', edgecolor='red', alpha=0.4)
ax.add_geometries([buffered_eddy], crs=ccrs.epsg(6932), facecolor='none', edgecolor='red', linewidth=2, linestyle='--', alpha=0.8)
# elocs = ax.scatter(expert_locs['x'], expert_locs['y'], transform=ccrs.epsg(3031), color='black', s=10, label='Expert locations')
## plot grid
ax.scatter(sral_df['lon_20_ku'], sral_df['lat_20_ku'], transform=ccrs.PlateCarree(), color='blue', s=5, label='Grid')
ax.coastlines()
ax.gridlines(alpha=0.5)
eddy_proxy = mlines.Line2D([], [], color='red', linewidth=4, alpha=0.8, label="Selected known eddy")
buffer_proxy = mlines.Line2D([], [], color='red', linewidth=2, linestyle='--', alpha=0.8, label=f"{int(buffer/1e3)} km Buffer zone")
ax.legend(handles=[eddy_proxy, buffer_proxy, elocs], loc='lower left')
plt.show()
# Out:
# We have reduced the number of observations from 349337 to 2941

# %%
# Plot the eddy, buffer and the bounds
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': ccrs.SouthPolarStereo()})
ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
ax.add_geometries(selected_eddy.geometry, crs=ccrs.PlateCarree(), facecolor='red', edgecolor='red', alpha=0.4)
ax.add_geometries([buffered_eddy], crs=ccrs.epsg(6932), facecolor='none', edgecolor='red', linewidth=2, linestyle='--', alpha=0.8)
elocs = ax.scatter(expert_locs['x'], expert_locs['y'], transform=ccrs.epsg(6932), color='black', s=10, label='Expert locations')
## plot grid
ax.scatter(gridded_obvs_df['x'], gridded_obvs_df['y'], transform=ccrs.epsg(6932), color='blue', s=5, label='Grid')
ax.coastlines()
ax.gridlines(alpha=0.5)
eddy_proxy = mlines.Line2D([], [], color='red', linewidth=4, alpha=0.8, label="Selected known eddy")
buffer_proxy = mlines.Line2D([], [], color='red', linewidth=2, linestyle='--', alpha=0.8, label=f"{int(buffer/1e3)} km Buffer zone")
ax.legend(handles=[eddy_proxy, buffer_proxy, elocs], loc='lower left')
plt.show()

# %%
sral_df = sral_df.dropna(subset=['x', 'y', 't','ssha_20_ku']).reset_index(drop=True)
print(sral_df.shape)
# Out:
# (346030, 18)

# %% [markdown]
# ### Set GPSat configuration parameters

# %%
# Set training and inference radius
training_radius = 100_000
inference_radius = 50_000

# %%
# Local expert locations config
local_expert = ExpertLocsConfig(source = expert_locs)

# Model config
model = ModelConfig(oi_model = "GPflowSGPRModel", # Use GPflow SGPR model
# model = ModelConfig(oi_model = "GPflowGPRModel", # Use GPflow GPR model
                    init_params = {
                        # normalise xy coordinates
                        "coords_scale": [10_000, 10_000, 1],
                        'num_inducing_points':100
                        },
                    constraints = {
                        # set bounds on the lengthscale hyperparameters
                        "lengthscales": {
                            "low": [1e-08, 1e-08, 1e-08],
                            "high": [600_000, 600_000, 9]
                        }
                        }
                    )

# Data config
data = DataConfig(data_source = sral_df,
                  obs_col = ssha_var,
                  coords_col = ["x", "y", "t"],
                  local_select = [
                    # Select data within the training window and radius
                    {"col": "t", "comp": "<=", "val": training_window.days},
                    {"col": "t", "comp": ">=", "val": -training_window.days},
                    {"col": ["x", "y"], "comp": "<", "val": training_radius}
                  ]
                )

# Prediction locs config
pred_loc = PredictionLocsConfig(method = "from_dataframe",
                                df = pred_locs,
                                max_dist = inference_radius)

# %%
locexp = LocalExpertOI(expert_loc_config = local_expert,
                       data_config = data,
                       model_config = model,
                       pred_loc_config = pred_loc)
# Out:
# in json_serializable - key: 'source' has value DataFrame/Series, but is too long: 600 >  100
# storing as str
# 'data_select': 0.000 seconds
# 'load': 0.001 seconds
# in json_serializable - key: 'data_source' has value DataFrame/Series, but is too long: 346030 >  100
# storing as str
# in json_serializable - key: 'df' has value DataFrame/Series, but is too long: 13680 >  100
# storing as str

# %% [markdown]
# ### Run GPSat

# %%
# path to store results
store_path = week8_path / 'OI_results' / f'Eddy_num_{eddy_number}_{date.strftime("%Y-%m-%d")}_{ssha_var}.h5'
if store_path.parent.exists() == False:
    store_path.parent.mkdir(parents=True)

# %%
# for the purposes of a simple example, if store_path exists: delete it
if os.path.exists(store_path):
    cprint(f"removing: {store_path}")
    os.remove(store_path)
    # print(f'skipping {store_path}')

# run optimal interpolation
locexp.run(store_path=str(store_path))
# Out:
# Streaming output truncated to the last 5000 lines.
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 8.38 seconds
# --------------------------------------------------
# 401 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 400  2.399052e+06  2.538319e+06  43.384303 -58.297566  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 4055
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.050 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 4.699 seconds
# 'optimise_parameters': 4.699 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([12.59618743, 15.14868913,  8.64469056])
# kernel_variance: 0.004375499146438162
# likelihood_variance: 0.003118113441296886
# inducing_points: array([[  238.31232568,   260.78199333, 17898.        ],
#        [  230.49375474,   256.64419517, 17898.        ],
#        [  238.65979535,   260.96498801, 17898.        ],
#        [  234.87681292,   250.95525557, 17904.        ],
#        [  237.17578836,   254.1245539 , 17902.        ]]) (truncated)
# 'predict': 0.173 seconds
# total run time : 7.01 seconds
# --------------------------------------------------
# 402 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 401  2.424052e+06  2.538319e+06  43.680901 -58.13683  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 3853
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 7.116 seconds
# 'optimise_parameters': 7.116 seconds
# 'get_parameters': 0.014 seconds
# parameters:
# lengthscales: array([ 8.35852672, 12.06777168,  8.99989341])
# kernel_variance: 0.0024135709296402774
# likelihood_variance: 0.002931069269653651
# inducing_points: array([[  241.49096717,   259.53833034, 17894.        ],
#        [  243.34395954,   250.31716361, 17898.        ],
#        [  238.81232033,   246.06468428, 17893.        ],
#        [  248.15330154,   261.06549298, 17898.        ],
#        [  251.10629019,   254.27414493, 17902.        ]]) (truncated)
# 'predict': 0.266 seconds
# total run time : 9.58 seconds
# --------------------------------------------------
# 403 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 402  2.449052e+06  2.538319e+06  43.974595 -57.975155  17897.0         True
# 'local_data_select': 0.140 seconds
# number obs: 3486
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.054 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 4.108 seconds
# 'optimise_parameters': 4.109 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([6.8391808 , 8.54555158, 5.06799936])
# kernel_variance: 0.0012044360581525346
# likelihood_variance: 0.0029640725886822244
# inducing_points: array([[  246.54457533,   257.45357546, 17898.        ],
#        [  244.53446513,   257.85640568, 17902.        ],
#        [  239.17604941,   261.15473814, 17904.        ],
#        [  244.45875857,   248.77489503, 17893.        ],
#        [  238.6651567 ,   254.88255586, 17902.        ]]) (truncated)
# 'predict': 0.166 seconds
# total run time : 6.45 seconds
# --------------------------------------------------
# 404 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 403  2.474052e+06  2.538319e+06  44.265412 -57.812554  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 2977
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.041 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 3.936 seconds
# 'optimise_parameters': 3.936 seconds
# 'get_parameters': 0.014 seconds
# parameters:
# lengthscales: array([5.94664417e+01, 5.18395619e+01, 1.98510819e-08])
# kernel_variance: 5.157614788641751
# likelihood_variance: 0.0035059399849706957
# inducing_points: array([[  257.13654163,   254.79102733, 17893.        ],
#        [  247.42303152,   259.42378744, 17898.        ],
#        [  246.23228118,   249.62225568, 17893.        ],
#        [  247.03732683,   258.55810008, 17898.        ],
#        [  249.89004055,   251.66649425, 17902.        ]]) (truncated)
# 'predict': 0.236 seconds
# total run time : 6.78 seconds
# --------------------------------------------------
# 405 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 404  2.499052e+06  2.538319e+06  44.553381 -57.649036  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 2919
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.042 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 3.168 seconds
# 'optimise_parameters': 3.168 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([31.09622599,  3.15019214,  1.19433408])
# kernel_variance: 0.00043917396013249863
# likelihood_variance: 0.0030360527953151636
# inducing_points: array([[  259.87880415,   253.40087728, 17893.        ],
#        [  251.72738064,   246.24175935, 17897.        ],
#        [  242.44123845,   248.31612035, 17898.        ],
#        [  257.55015443,   254.98569064, 17893.        ],
#        [  258.34776119,   250.29824311, 17893.        ]]) (truncated)
# 'predict': 0.173 seconds
# total run time : 5.48 seconds
# --------------------------------------------------
# 406 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 405  2.524052e+06  2.538319e+06  44.838527 -57.484614  17897.0         True
# 'local_data_select': 0.121 seconds
# number obs: 2990
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.042 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 4.302 seconds
# 'optimise_parameters': 4.303 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([56.94672665,  3.51004352,  1.97265546])
# kernel_variance: 0.0004005682465258958
# likelihood_variance: 0.0030581438333674
# inducing_points: array([[  258.99198464,   249.54285775, 17897.        ],
#        [  258.82505668,   251.26420081, 17893.        ],
#        [  244.45875857,   248.77489503, 17893.        ],
#        [  257.57970429,   254.99959052, 17893.        ],
#        [  245.14221159,   254.31866742, 17898.        ]]) (truncated)
# 'predict': 0.216 seconds
# total run time : 7.19 seconds
# --------------------------------------------------
# 407 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 406  2.549052e+06  2.538319e+06  45.120879 -57.319296  17897.0         True
# 'local_data_select': 0.172 seconds
# number obs: 2827
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.073 seconds
# 'set_lengthscales_constraints': 0.016 seconds
# **********
# optimization failed!
# 'optimise_parameters': 8.260 seconds
# 'optimise_parameters': 8.261 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([59.19246016,  3.14919302,  0.13419909])
# kernel_variance: 0.0004145525796567815
# likelihood_variance: 0.0030475792085234814
# inducing_points: array([[  258.8204591 ,   255.58291983, 17893.        ],
#        [  255.24090917,   247.84216549, 17897.        ],
#        [  248.5167921 ,   248.73249964, 17902.        ],
#        [  255.22372321,   244.00404882, 17893.        ],
#        [  261.71954362,   257.14696897, 17893.        ]]) (truncated)
# 'predict': 0.157 seconds
# total run time : 10.65 seconds
# --------------------------------------------------
# 408 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 407  2.574052e+06  2.538319e+06  45.400463 -57.153095  17897.0         True
# 'local_data_select': 0.117 seconds
# number obs: 2826
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.045 seconds
# 'set_lengthscales_constraints': 0.019 seconds
# **********
# optimization failed!
# 'optimise_parameters': 6.669 seconds
# 'optimise_parameters': 6.670 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([8.84937297, 4.46582754, 1.01817581])
# kernel_variance: 0.0007943230690598443
# likelihood_variance: 0.0032126179227906283
# inducing_points: array([[  257.50747031,   248.60045345, 17893.        ],
#        [  251.86241085,   261.53951225, 17902.        ],
#        [  264.25992232,   251.91746404, 17897.        ],
#        [  259.84996577,   253.34233402, 17893.        ],
#        [  261.16482485,   250.52425085, 17897.        ]]) (truncated)
# 'predict': 0.171 seconds
# total run time : 8.99 seconds
# --------------------------------------------------
# 409 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 408  1.999052e+06  2.563319e+06  37.949551 -60.549308  17897.0         True
# 'local_data_select': 0.130 seconds
# number obs: 4890
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.048 seconds
# 'set_lengthscales_constraints': 0.015 seconds
# 'optimise_parameters': 5.184 seconds
# 'optimise_parameters': 5.185 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([8.38910688, 5.51666183, 8.99943755])
# kernel_variance: 0.0019971884031820017
# likelihood_variance: 0.0043056101830458975
# inducing_points: array([[  200.21430016,   260.92358277, 17903.        ],
#        [  206.81119871,   249.48433857, 17894.        ],
#        [  198.86941691,   247.72205288, 17904.        ],
#        [  201.62408052,   260.89760496, 17896.        ],
#        [  202.78813154,   255.74103464, 17900.        ]]) (truncated)
# 'predict': 0.172 seconds
# total run time : 7.61 seconds
# --------------------------------------------------
# 410 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 409  2.024052e+06  2.563319e+06  38.295384 -60.406065  17897.0         True
# 'local_data_select': 0.167 seconds
# number obs: 5116
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.075 seconds
# 'set_lengthscales_constraints': 0.015 seconds
# 'optimise_parameters': 6.944 seconds
# 'optimise_parameters': 6.944 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([12.62313989,  8.66862272,  8.99997202])
# kernel_variance: 0.006558569757321179
# likelihood_variance: 0.004205541960331369
# inducing_points: array([[  209.20635577,   253.68476508, 17904.        ],
#        [  210.94848794,   254.68276132, 17904.        ],
#        [  205.17939944,   251.69548097, 17897.        ],
#        [  204.63019543,   248.24950951, 17894.        ],
#        [  201.16524021,   264.07320457, 17903.        ]]) (truncated)
# 'predict': 0.193 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 10.31 seconds
# --------------------------------------------------
# 411 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 410  2.049052e+06  2.563319e+06  38.637952 -60.261678  17897.0         True
# 'local_data_select': 0.118 seconds
# number obs: 4801
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.045 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 6.483 seconds
# 'optimise_parameters': 6.484 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([7.36461798, 6.56182455, 8.99998718])
# kernel_variance: 0.002777335100783297
# likelihood_variance: 0.004323980292247219
# inducing_points: array([[  213.46183332,   256.11902347, 17904.        ],
#        [  208.64793726,   250.52185717, 17894.        ],
#        [  213.49838303,   253.25118804, 17894.        ],
#        [  204.36453918,   265.70484666, 17893.        ],
#        [  205.72864434,   253.35322032, 17897.        ]]) (truncated)
# 'predict': 0.245 seconds
# total run time : 9.32 seconds
# --------------------------------------------------
# 412 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 411  2.074052e+06  2.563319e+06  38.977276 -60.11616  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4714
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.044 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 5.826 seconds
# 'optimise_parameters': 5.826 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([8.05209463, 8.3794968 , 8.99999419])
# kernel_variance: 0.0033094544130019
# likelihood_variance: 0.004264955874750243
# inducing_points: array([[  201.97519361,   258.00564145, 17893.        ],
#        [  213.18509062,   259.65531581, 17901.        ],
#        [  209.80629639,   265.92307555, 17896.        ],
#        [  208.23844744,   260.98201432, 17897.        ],
#        [  210.0287179 ,   250.54595009, 17901.        ]]) (truncated)
# 'predict': 0.170 seconds
# total run time : 8.17 seconds
# --------------------------------------------------
# 413 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 412  2.099052e+06  2.563319e+06  39.313379 -59.969524  17897.0         True
# 'local_data_select': 0.111 seconds
# number obs: 4563
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.044 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 6.368 seconds
# 'optimise_parameters': 6.369 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([8.42088021, 7.41441786, 8.99999106])
# kernel_variance: 0.0039078789755375605
# likelihood_variance: 0.0037392119357484697
# inducing_points: array([[  209.83334714,   249.98610322, 17901.        ],
#        [  213.87944327,   262.31884131, 17900.        ],
#        [  207.84870477,   255.83438055, 17890.        ],
#        [  211.19737805,   253.90449674, 17901.        ],
#        [  205.1690144 ,   251.66419358, 17897.        ]]) (truncated)
# 'predict': 0.175 seconds
# total run time : 8.71 seconds
# --------------------------------------------------
# 414 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 413  2.124052e+06  2.563319e+06  39.646284 -59.821786  17897.0         True
# 'local_data_select': 0.119 seconds
# number obs: 4384
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 4.967 seconds
# 'optimise_parameters': 4.968 seconds
# 'get_parameters': 0.010 seconds
# parameters:
# lengthscales: array([8.23097206, 6.56861375, 8.99997868])
# kernel_variance: 0.002915193673168531
# likelihood_variance: 0.003927617332674636
# inducing_points: array([[  211.11984831,   254.7808174 , 17904.        ],
#        [  217.8324765 ,   255.67703941, 17894.        ],
#        [  219.16879468,   253.59771591, 17892.        ],
#        [  209.86121811,   259.94542241, 17900.        ],
#        [  219.40940413,   254.24448433, 17892.        ]]) (truncated)
# 'predict': 0.172 seconds
# total run time : 7.36 seconds
# --------------------------------------------------
# 415 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 414  2.149052e+06  2.563319e+06  39.976014 -59.672957  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4208
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.056 seconds
# 'set_lengthscales_constraints': 0.016 seconds
# 'optimise_parameters': 6.928 seconds
# 'optimise_parameters': 6.928 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([6.36202685, 5.82329497, 8.99996807])
# kernel_variance: 0.002524695470715754
# likelihood_variance: 0.003971074779438584
# inducing_points: array([[  213.76624446,   262.25212781, 17900.        ],
#        [  221.90480675,   260.98732362, 17892.        ],
#        [  206.83306415,   256.69927955, 17897.        ],
#        [  222.68800245,   261.35570582, 17904.        ],
#        [  214.24143942,   262.73159578, 17901.        ]]) (truncated)
# 'predict': 0.179 seconds
# total run time : 9.31 seconds
# --------------------------------------------------
# 416 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 415  2.174052e+06  2.563319e+06  40.302593 -59.523052  17897.0         True
# 'local_data_select': 0.121 seconds
# number obs: 4178
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# **********
# optimization failed!
# 'optimise_parameters': 7.240 seconds
# 'optimise_parameters': 7.240 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([4.17338712, 7.61156548, 0.18785158])
# kernel_variance: 0.0017766415904138758
# likelihood_variance: 0.003990150892947649
# inducing_points: array([[  217.34737272,   261.34915116, 17890.        ],
#        [  214.12432453,   262.3898438 , 17901.        ],
#        [  222.01815308,   261.29512246, 17892.        ],
#        [  217.55837941,   264.48226283, 17900.        ],
#        [  216.09594055,   260.6260314 , 17890.        ]]) (truncated)
# 'predict': 0.261 seconds
# total run time : 10.17 seconds
# --------------------------------------------------
# 417 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 416  2.199052e+06  2.563319e+06  40.626044 -59.372084  17897.0         True
# 'local_data_select': 0.126 seconds
# number obs: 4208
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.048 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 5.012 seconds
# 'optimise_parameters': 5.013 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([8.01080324, 8.1302199 , 8.99997546])
# kernel_variance: 0.004780061632945973
# likelihood_variance: 0.003900091676944122
# inducing_points: array([[  217.18937671,   248.29921449, 17892.        ],
#        [  218.24368437,   250.08343819, 17898.        ],
#        [  214.37975809,   263.13545936, 17901.        ],
#        [  220.83680283,   258.09356183, 17892.        ],
#        [  217.68896302,   255.59690517, 17894.        ]]) (truncated)
# 'predict': 0.167 seconds
# total run time : 7.37 seconds
# --------------------------------------------------
# 418 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 417  2.224052e+06  2.563319e+06  40.946393 -59.220065  17897.0         True
# 'local_data_select': 0.111 seconds
# number obs: 4290
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.046 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 6.722 seconds
# 'optimise_parameters': 6.722 seconds
# 'get_parameters': 0.013 seconds
# parameters:
# lengthscales: array([12.39259654, 10.11049653,  8.99997712])
# kernel_variance: 0.0058832402943351314
# likelihood_variance: 0.003938268253375385
# inducing_points: array([[  224.06136612,   259.14207678, 17894.        ],
#        [  219.85564591,   255.44554658, 17892.        ],
#        [  221.85107962,   257.91541314, 17894.        ],
#        [  218.37472063,   258.91450254, 17904.        ],
#        [  226.97527494,   259.4906392 , 17896.        ]]) (truncated)
# 'predict': 0.253 seconds
# total run time : 9.39 seconds
# --------------------------------------------------
# 419 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 418  2.249052e+06  2.563319e+06  41.263663 -59.067008  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4385
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 3.743 seconds
# 'optimise_parameters': 3.744 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([3.66080707e+00, 1.72086829e+00, 1.05212393e-08])
# kernel_variance: 0.00012017377752926045
# likelihood_variance: 0.002825606274743595
# inducing_points: array([[  221.13965658,   251.6429892 , 17898.        ],
#        [  223.96109974,   251.71967865, 17896.        ],
#        [  222.66919825,   248.41423203, 17896.        ],
#        [  227.64948324,   261.1266596 , 17894.        ],
#        [  231.53629477,   257.19816986, 17898.        ]]) (truncated)
# 'predict': 0.172 seconds
# total run time : 6.11 seconds
# --------------------------------------------------
# 420 / 600
# current local expert:
#                 x             y       lon        lat        t  is_in_ocean
# 419  2.274052e+06  2.563319e+06  41.57788 -58.912926  17897.0         True
# 'local_data_select': 0.110 seconds
# number obs: 4653
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 4.900 seconds
# 'optimise_parameters': 4.900 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([13.63855814, 17.41119191,  2.68283589])
# kernel_variance: 0.002613435452450649
# likelihood_variance: 0.0037481041289039413
# inducing_points: array([[  228.6220829 ,   263.77196931, 17896.        ],
#        [  228.42452162,   261.55423335, 17894.        ],
#        [  225.84107755,   260.1274736 , 17894.        ],
#        [  221.86366012,   252.03206053, 17898.        ],
#        [  230.92187313,   262.9293263 , 17894.        ]]) (truncated)
# 'predict': 0.250 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 8.73 seconds
# --------------------------------------------------
# 421 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 420  2.299052e+06  2.563319e+06  41.889069 -58.757832  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 4659
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.045 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 4.421 seconds
# 'optimise_parameters': 4.421 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([13.48526499, 14.57249626,  3.88888745])
# kernel_variance: 0.00253903533032347
# likelihood_variance: 0.0035586183570328377
# inducing_points: array([[  239.80003967,   255.59849457, 17894.        ],
#        [  238.58108343,   252.77090569, 17894.        ],
#        [  233.03930366,   253.27267128, 17890.        ],
#        [  228.87004087,   250.07742498, 17900.        ],
#        [  225.83119569,   254.15825063, 17898.        ]]) (truncated)
# 'predict': 0.179 seconds
# total run time : 6.78 seconds
# --------------------------------------------------
# 422 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 421  2.324052e+06  2.563319e+06  42.197256 -58.601737  17897.0         True
# 'local_data_select': 0.118 seconds
# number obs: 4540
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 5.020 seconds
# 'optimise_parameters': 5.021 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([14.26949364, 16.38038324,  4.61908578])
# kernel_variance: 0.0025439378663255283
# likelihood_variance: 0.0034681601007325153
# inducing_points: array([[  236.62093942,   253.84181673, 17902.        ],
#        [  228.21230156,   248.46616824, 17900.        ],
#        [  231.85484004,   257.3672986 , 17898.        ],
#        [  225.29437288,   255.14677451, 17896.        ],
#        [  231.1911607 ,   255.79147893, 17900.        ]]) (truncated)
# 'predict': 0.245 seconds
# total run time : 7.81 seconds
# --------------------------------------------------
# 423 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 422  2.349052e+06  2.563319e+06  42.502465 -58.444654  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 4204
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 4.149 seconds
# 'optimise_parameters': 4.150 seconds
# 'get_parameters': 0.015 seconds
# parameters:
# lengthscales: array([19.49741622, 14.35112207,  4.36716577])
# kernel_variance: 0.003953068234010532
# likelihood_variance: 0.0032755892870214563
# inducing_points: array([[  235.12319741,   265.57312642, 17900.        ],
#        [  231.36421629,   249.24246009, 17890.        ],
#        [  235.13289118,   251.55895489, 17904.        ],
#        [  235.6863741 ,   253.36516071, 17902.        ],
#        [  232.86839124,   257.90500306, 17898.        ]]) (truncated)
# 'predict': 0.175 seconds
# total run time : 6.52 seconds
# --------------------------------------------------
# 424 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 423  2.374052e+06  2.563319e+06  42.804724 -58.286594  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 4217
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 5.493 seconds
# 'optimise_parameters': 5.494 seconds
# 'get_parameters': 0.013 seconds
# parameters:
# lengthscales: array([14.20419942, 15.8825427 ,  6.66771679])
# kernel_variance: 0.005295381873003903
# likelihood_variance: 0.003226870361559297
# inducing_points: array([[  240.96406434,   265.43765294, 17904.        ],
#        [  228.03219182,   255.33346985, 17898.        ],
#        [  229.16159515,   255.93533141, 17898.        ],
#        [  237.40252427,   263.87342497, 17890.        ],
#        [  232.99304434,   260.25785312, 17900.        ]]) (truncated)
# 'predict': 0.226 seconds
# total run time : 8.26 seconds
# --------------------------------------------------
# 425 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 424  2.399052e+06  2.563319e+06  43.104058 -58.127569  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 4047
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 5.564 seconds
# 'optimise_parameters': 5.564 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([13.89307696, 15.57796444,  8.99984904])
# kernel_variance: 0.0044858391458807104
# likelihood_variance: 0.0031495056734294215
# inducing_points: array([[  236.58473905,   261.87502809, 17890.        ],
#        [  240.92404423,   258.21512762, 17894.        ],
#        [  233.72958687,   252.3653912 , 17902.        ],
#        [  236.25714213,   254.21498884, 17904.        ],
#        [  239.01559162,   255.06071317, 17902.        ]]) (truncated)
# 'predict': 0.163 seconds
# total run time : 7.92 seconds
# --------------------------------------------------
# 426 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 425  2.424052e+06  2.563319e+06  43.400493 -57.967591  17897.0         True
# 'local_data_select': 0.111 seconds
# number obs: 3905
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.042 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 7.474 seconds
# 'optimise_parameters': 7.475 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([ 8.3789267 , 13.32055323,  8.99975049])
# kernel_variance: 0.0021810826559123214
# likelihood_variance: 0.0030207015699662766
# inducing_points: array([[  236.36131699,   261.32998326, 17890.        ],
#        [  237.74550096,   257.74560724, 17904.        ],
#        [  237.13019962,   263.20735167, 17890.        ],
#        [  245.12882294,   254.28879776, 17898.        ],
#        [  248.30825604,   248.28790536, 17902.        ]]) (truncated)
# 'predict': 0.166 seconds
# total run time : 9.87 seconds
# --------------------------------------------------
# 427 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 426  2.449052e+06  2.563319e+06  43.694055 -57.806671  17897.0         True
# 'local_data_select': 0.115 seconds
# number obs: 3669
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.042 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# **********
# optimization failed!
# 'optimise_parameters': 6.084 seconds
# 'optimise_parameters': 6.084 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([10.3823558 ,  8.91913323,  0.15725149])
# kernel_variance: 0.0012675081275289263
# likelihood_variance: 0.0029813925650910363
# inducing_points: array([[  246.98702419,   259.09277334, 17902.        ],
#        [  236.48810505,   259.82001799, 17898.        ],
#        [  242.77380222,   247.9681241 , 17893.        ],
#        [  239.99174979,   261.66575177, 17898.        ],
#        [  238.48062959,   259.49555418, 17904.        ]]) (truncated)
# 'predict': 0.249 seconds
# total run time : 8.97 seconds
# --------------------------------------------------
# 428 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 427  2.474052e+06  2.563319e+06  43.984771 -57.64482  17897.0         True
# 'local_data_select': 0.175 seconds
# number obs: 3266
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.064 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 5.808 seconds
# 'optimise_parameters': 5.808 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([4.27404182, 5.81518668, 8.99998557])
# kernel_variance: 0.0004543957118376696
# likelihood_variance: 0.0028345396150993222
# inducing_points: array([[  237.87236581,   258.04732494, 17904.        ],
#        [  244.71118444,   264.13969954, 17898.        ],
#        [  249.43286569,   250.6885186 , 17902.        ],
#        [  246.18775908,   264.91083247, 17898.        ],
#        [  239.47630566,   254.84651035, 17894.        ]]) (truncated)
# 'predict': 0.165 seconds
# total run time : 8.30 seconds
# --------------------------------------------------
# 429 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 428  2.499052e+06  2.563319e+06  44.272667 -57.482049  17897.0         True
# 'local_data_select': 0.115 seconds
# number obs: 2844
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.068 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 4.512 seconds
# 'optimise_parameters': 4.512 seconds
# 'get_parameters': 0.013 seconds
# parameters:
# lengthscales: array([14.91315749,  4.5257619 ,  0.91865025])
# kernel_variance: 0.0005519658286379524
# likelihood_variance: 0.0027921114898735535
# inducing_points: array([[  241.76053102,   256.45356097, 17902.        ],
#        [  244.16109642,   263.85206582, 17898.        ],
#        [  250.04490177,   251.43752749, 17893.        ],
#        [  243.38431568,   250.40674804, 17898.        ],
#        [  245.02040094,   249.04344016, 17893.        ]]) (truncated)
# 'predict': 0.217 seconds
# total run time : 7.52 seconds
# --------------------------------------------------
# 430 / 600
# current local expert:
#                 x             y       lon        lat        t  is_in_ocean
# 429  2.524052e+06  2.563319e+06  44.55777 -57.318368  17897.0         True
# 'local_data_select': 0.180 seconds
# number obs: 2863
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.055 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 4.111 seconds
# 'optimise_parameters': 4.111 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([59.99637643,  3.84020835,  1.47545623])
# kernel_variance: 0.0004296200789777735
# likelihood_variance: 0.002957489403230334
# inducing_points: array([[  251.04502403,   261.1303278 , 17902.        ],
#        [  254.22676742,   262.72080294, 17902.        ],
#        [  246.22454839,   256.73705646, 17898.        ],
#        [  245.41041275,   258.29841191, 17902.        ],
#        [  257.60897392,   248.8053568 , 17893.        ]]) (truncated)
# 'predict': 0.157 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 7.84 seconds
# --------------------------------------------------
# 431 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 430  2.549052e+06  2.563319e+06  44.840106 -57.15379  17897.0         True
# 'local_data_select': 0.116 seconds
# number obs: 2915
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# **********
# optimization failed!
# 'optimise_parameters': 6.687 seconds
# 'optimise_parameters': 6.688 seconds
# 'get_parameters': 0.012 seconds
# parameters:
# lengthscales: array([59.99999448,  4.11324614,  0.18764021])
# kernel_variance: 0.0004480141512527102
# likelihood_variance: 0.0029674886834904564
# inducing_points: array([[  263.0370948 ,   259.83908931, 17893.        ],
#        [  248.21961248,   261.21473639, 17898.        ],
#        [  260.00211528,   256.13761036, 17893.        ],
#        [  260.78589958,   255.24472166, 17893.        ],
#        [  245.24926329,   254.55753197, 17898.        ]]) (truncated)
# 'predict': 0.254 seconds
# total run time : 9.26 seconds
# --------------------------------------------------
# 432 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 431  2.574052e+06  2.563319e+06  45.119702 -56.988323  17897.0         True
# 'local_data_select': 0.121 seconds
# number obs: 2843
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.069 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 3.476 seconds
# 'optimise_parameters': 3.476 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([52.48435331,  3.12665845,  0.99438492])
# kernel_variance: 0.00027820498650340576
# likelihood_variance: 0.0031273094372726656
# inducing_points: array([[  261.9088722 ,   250.85968542, 17897.        ],
#        [  262.77863194,   257.43768992, 17893.        ],
#        [  265.92903029,   252.92003776, 17897.        ],
#        [  256.70768168,   263.95662177, 17902.        ],
#        [  264.8011582 ,   250.71405396, 17897.        ]]) (truncated)
# 'predict': 0.163 seconds
# total run time : 5.93 seconds
# --------------------------------------------------
# 433 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 432  1.999052e+06  2.588319e+06  37.680203 -60.365996  17897.0         True
# 'local_data_select': 0.116 seconds
# number obs: 4489
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.045 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 8.198 seconds
# 'optimise_parameters': 8.199 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([8.90468068, 5.30276329, 8.9999862 ])
# kernel_variance: 0.0025644825770653064
# likelihood_variance: 0.004064785879685708
# inducing_points: array([[  200.83627028,   254.57483775, 17900.        ],
#        [  196.75787844,   249.6084183 , 17903.        ],
#        [  196.6784777 ,   252.08202911, 17900.        ],
#        [  199.32686242,   259.47826457, 17896.        ],
#        [  202.95241562,   250.08568967, 17904.        ]]) (truncated)
# 'predict': 0.179 seconds
# total run time : 10.65 seconds
# --------------------------------------------------
# 434 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 433  2.024052e+06  2.588319e+06  38.025224 -60.223551  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4674
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.047 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 5.326 seconds
# 'optimise_parameters': 5.327 seconds
# 'get_parameters': 0.014 seconds
# parameters:
# lengthscales: array([9.47311023, 6.0269903 , 8.99997044])
# kernel_variance: 0.0032802295056861153
# likelihood_variance: 0.00423881122488856
# inducing_points: array([[  201.55361875,   265.36423321, 17903.        ],
#        [  206.55494992,   255.85507047, 17897.        ],
#        [  206.45184029,   255.54236608, 17897.        ],
#        [  202.47484209,   252.68770433, 17890.        ],
#        [  196.25646916,   265.23832073, 17899.        ]]) (truncated)
# 'predict': 0.177 seconds
# total run time : 7.85 seconds
# --------------------------------------------------
# 435 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 434  2.049052e+06  2.588319e+06  38.367025 -60.079959  17897.0         True
# 'local_data_select': 0.177 seconds
# number obs: 4848
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.117 seconds
# 'set_lengthscales_constraints': 0.033 seconds
# 'optimise_parameters': 6.400 seconds
# 'optimise_parameters': 6.402 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([6.80202459, 4.68690811, 8.54765644])
# kernel_variance: 0.0017540730454212146
# likelihood_variance: 0.004283223936423648
# inducing_points: array([[  202.54365016,   259.8288476 , 17893.        ],
#        [  200.37103457,   251.45055407, 17890.        ],
#        [  203.35620345,   253.2051119 , 17890.        ],
#        [  209.61010287,   265.80311682, 17896.        ],
#        [  211.3052823 ,   254.21543812, 17901.        ]]) (truncated)
# 'predict': 0.180 seconds
# total run time : 9.07 seconds
# --------------------------------------------------
# 436 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 435  2.074052e+06  2.588319e+06  38.705629 -59.935234  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 4758
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.044 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 4.658 seconds
# 'optimise_parameters': 4.659 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([10.15220611,  6.651166  ,  8.99858533])
# kernel_variance: 0.00543907280245674
# likelihood_variance: 0.004164068686142415
# inducing_points: array([[  207.39622329,   264.44767178, 17896.        ],
#        [  213.42665782,   262.05194548, 17900.        ],
#        [  204.77428747,   250.475449  , 17897.        ],
#        [  205.23850593,   263.12332444, 17896.        ],
#        [  216.29502329,   260.74113514, 17890.        ]]) (truncated)
# 'predict': 0.199 seconds
# total run time : 7.37 seconds
# --------------------------------------------------
# 437 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 436  2.099052e+06  2.588319e+06  39.041056 -59.78939  17897.0         True
# 'local_data_select': 0.168 seconds
# number obs: 4380
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.068 seconds
# 'set_lengthscales_constraints': 0.016 seconds
# 'optimise_parameters': 6.075 seconds
# 'optimise_parameters': 6.076 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([5.6490101 , 6.07753208, 8.99997553])
# kernel_variance: 0.0019617328831867506
# likelihood_variance: 0.003928073142054953
# inducing_points: array([[  218.40655794,   255.99745024, 17894.        ],
#        [  209.69145415,   259.84490319, 17900.        ],
#        [  205.85280959,   253.72855142, 17897.        ],
#        [  205.12642465,   263.0544433 , 17896.        ],
#        [  211.46023941,   257.93826934, 17890.        ]]) (truncated)
# 'predict': 0.168 seconds
# total run time : 8.64 seconds
# --------------------------------------------------
# 438 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 437  2.124052e+06  2.588319e+06  39.373327 -59.64244  17897.0         True
# 'local_data_select': 0.115 seconds
# number obs: 4346
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.045 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 6.528 seconds
# 'optimise_parameters': 6.529 seconds
# 'get_parameters': 0.014 seconds
# parameters:
# lengthscales: array([5.52784146, 6.94388806, 8.99998676])
# kernel_variance: 0.003436277561753211
# likelihood_variance: 0.003909176721660272
# inducing_points: array([[  207.63560498,   252.78323962, 17904.        ],
#        [  221.24826391,   257.58031129, 17894.        ],
#        [  211.63944452,   255.17925962, 17901.        ],
#        [  206.55494992,   255.85507047, 17897.        ],
#        [  206.83575381,   264.10398513, 17896.        ]]) (truncated)
# 'predict': 0.239 seconds
# total run time : 9.53 seconds
# --------------------------------------------------
# 439 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 438  2.149052e+06  2.588319e+06  39.702466 -59.494398  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 4378
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 4.748 seconds
# 'optimise_parameters': 4.748 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([8.70849129, 8.7677253 , 8.99995296])
# kernel_variance: 0.00528241663256685
# likelihood_variance: 0.004014361885387827
# inducing_points: array([[  220.43796654,   257.01595034, 17892.        ],
#        [  220.80264891,   258.00120844, 17892.        ],
#        [  219.53946992,   265.64346497, 17900.        ],
#        [  211.70048573,   261.03316722, 17900.        ],
#        [  209.04972236,   250.74852108, 17894.        ]]) (truncated)
# 'predict': 0.189 seconds
# total run time : 7.21 seconds
# --------------------------------------------------
# 440 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 439  2.174052e+06  2.588319e+06  40.028495 -59.345277  17897.0         True
# 'local_data_select': 0.110 seconds
# number obs: 4308
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.011 seconds
# 'optimise_parameters': 6.793 seconds
# 'optimise_parameters': 6.794 seconds
# 'get_parameters': 0.015 seconds
# parameters:
# lengthscales: array([7.3710259 , 7.71990505, 8.99994223])
# kernel_variance: 0.0037355680376351093
# likelihood_variance: 0.004002235087898082
# inducing_points: array([[  225.49616397,   255.66688458, 17896.        ],
#        [  224.93344328,   253.67801975, 17898.        ],
#        [  224.05918795,   262.12919984, 17904.        ],
#        [  214.91851057,   256.94953887, 17904.        ],
#        [  219.18025963,   253.62851887, 17892.        ]]) (truncated)
# 'predict': 0.264 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 10.34 seconds
# --------------------------------------------------
# 441 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 440  2.199052e+06  2.588319e+06  40.351437 -59.19509  17897.0         True
# 'local_data_select': 0.118 seconds
# number obs: 4234
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.044 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 5.974 seconds
# 'optimise_parameters': 5.974 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([6.99842489, 8.10125589, 8.99986226])
# kernel_variance: 0.005683102282739468
# likelihood_variance: 0.004000724576168462
# inducing_points: array([[  215.89556823,   267.57734204, 17901.        ],
#        [  212.18810344,   256.76474183, 17901.        ],
#        [  225.04489733,   254.50428053, 17896.        ],
#        [  223.20221537,   261.64592047, 17904.        ],
#        [  228.53999923,   263.55794264, 17896.        ]]) (truncated)
# 'predict': 0.187 seconds
# total run time : 8.80 seconds
# --------------------------------------------------
# 442 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 441  2.224052e+06  2.588319e+06  40.671316 -59.04385  17897.0         True
# 'local_data_select': 0.178 seconds
# number obs: 4314
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.068 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 6.279 seconds
# 'optimise_parameters': 6.279 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([ 4.88798235, 45.55594746,  0.53343195])
# kernel_variance: 0.0017743660255185412
# likelihood_variance: 0.0040371173931944395
# inducing_points: array([[  217.37581393,   261.36557147, 17890.        ],
#        [  220.73160562,   257.2929149 , 17894.        ],
#        [  216.80695058,   261.037006  , 17890.        ],
#        [  214.06164583,   256.46117416, 17904.        ],
#        [  222.11672304,   261.03308032, 17904.        ]]) (truncated)
# 'predict': 0.166 seconds
# total run time : 8.84 seconds
# --------------------------------------------------
# 443 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 442  2.249052e+06  2.588319e+06  40.988154 -58.891569  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4426
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.048 seconds
# 'set_lengthscales_constraints': 0.023 seconds
# 'optimise_parameters': 3.926 seconds
# 'optimise_parameters': 3.927 seconds
# 'get_parameters': 0.016 seconds
# parameters:
# lengthscales: array([10.16654965, 17.87017179,  4.41681717])
# kernel_variance: 0.0038524616668134224
# likelihood_variance: 0.004037436754612628
# inducing_points: array([[  219.74130048,   255.1375823 , 17892.        ],
#        [  230.49127568,   262.6925205 , 17894.        ],
#        [  229.74881992,   252.23563085, 17900.        ],
#        [  222.0807239 ,   258.0430044 , 17894.        ],
#        [  226.78639968,   259.00124096, 17896.        ]]) (truncated)
# 'predict': 0.256 seconds
# total run time : 7.00 seconds
# --------------------------------------------------
# 444 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 443  2.274052e+06  2.588319e+06  41.301977 -58.73826  17897.0         True
# 'local_data_select': 0.174 seconds
# number obs: 4674
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.088 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 5.279 seconds
# 'optimise_parameters': 5.280 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([10.84470234, 25.38660443,  2.10300572])
# kernel_variance: 0.002711691798735545
# likelihood_variance: 0.003946059048309598
# inducing_points: array([[  232.6384908 ,   259.37686546, 17900.        ],
#        [  221.13268133,   258.89404446, 17892.        ],
#        [  223.75665576,   268.10648921, 17900.        ],
#        [  224.81896709,   253.92293235, 17896.        ],
#        [  228.7250193 ,   267.87556369, 17890.        ]]) (truncated)
# 'predict': 0.178 seconds
# total run time : 7.88 seconds
# --------------------------------------------------
# 445 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 444  2.299052e+06  2.588319e+06  41.612808 -58.583936  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4849
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.010 seconds
# 'optimise_parameters': 5.588 seconds
# 'optimise_parameters': 5.588 seconds
# 'get_parameters': 0.016 seconds
# parameters:
# lengthscales: array([13.49554329, 25.43296721,  5.63427098])
# kernel_variance: 0.005612290327950044
# likelihood_variance: 0.003877844179757577
# inducing_points: array([[  235.40195409,   266.27153775, 17900.        ],
#        [  229.34850317,   250.11843855, 17902.        ],
#        [  229.94648588,   252.72194154, 17900.        ],
#        [  233.16404799,   260.68313215, 17900.        ],
#        [  226.27873605,   266.47962042, 17890.        ]]) (truncated)
# 'predict': 0.248 seconds
# total run time : 8.61 seconds
# --------------------------------------------------
# 446 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 445  2.324052e+06  2.588319e+06  41.920672 -58.428607  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 4817
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.048 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 3.829 seconds
# 'optimise_parameters': 3.830 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([14.56526452, 15.12837605,  3.75571444])
# kernel_variance: 0.0027364436936588537
# likelihood_variance: 0.003716432348694637
# inducing_points: array([[  228.41094191,   263.22160942, 17896.        ],
#        [  224.47005776,   253.42994145, 17898.        ],
#        [  235.74662528,   253.0077379 , 17904.        ],
#        [  237.40252427,   263.87342497, 17890.        ],
#        [  231.4778618 ,   249.51521632, 17890.        ]]) (truncated)
# 'predict': 0.173 seconds
# total run time : 6.33 seconds
# --------------------------------------------------
# 447 / 600
# ...
#        [  225.52796932,   270.8946434 , 17892.        ]]) (truncated)
# 'predict': 0.163 seconds
# total run time : 10.98 seconds
# --------------------------------------------------
# 586 / 600
# current local expert:
#                 x             y       lon        lat        t  is_in_ocean
# 585  2.224052e+06  2.738319e+06  39.08337 -57.970019  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 3488
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# 'optimise_parameters': 4.087 seconds
# 'optimise_parameters': 4.088 seconds
# 'get_parameters': 0.011 seconds
# parameters:
# lengthscales: array([26.69511418,  8.32848049,  1.26011493])
# kernel_variance: 0.0021866590103607306
# likelihood_variance: 0.0036679651522243235
# inducing_points: array([[  231.81501715,   272.14669982, 17896.        ],
#        [  220.25432554,   280.51909553, 17901.        ],
#        [  231.28509163,   269.33216715, 17890.        ],
#        [  217.24550945,   276.74024007, 17892.        ],
#        [  230.53798839,   268.78532261, 17896.        ]]) (truncated)
# 'predict': 0.162 seconds
# total run time : 7.08 seconds
# --------------------------------------------------
# 587 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 586  2.249052e+06  2.738319e+06  39.397145 -57.822271  17897.0         True
# 'local_data_select': 0.172 seconds
# number obs: 3678
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.064 seconds
# 'set_lengthscales_constraints': 0.017 seconds
# 'optimise_parameters': 5.266 seconds
# 'optimise_parameters': 5.266 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([10.5470618 ,  7.14699622,  0.80077286])
# kernel_variance: 0.001704529836660847
# likelihood_variance: 0.0038917135014089467
# inducing_points: array([[  218.38341259,   271.14097697, 17896.        ],
#        [  226.60866901,   273.87743012, 17892.        ],
#        [  224.54358076,   265.48705317, 17890.        ],
#        [  221.57632159,   279.44249008, 17892.        ],
#        [  229.37252906,   265.1147884 , 17904.        ]]) (truncated)
# 'predict': 0.166 seconds
# total run time : 8.28 seconds
# --------------------------------------------------
# 588 / 600
# current local expert:
#                 x             y        lon       lat        t  is_in_ocean
# 587  2.274052e+06  2.738319e+06  39.708122 -57.67348  17897.0         True
# 'local_data_select': 0.114 seconds
# number obs: 3794
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.013 seconds
# **********
# optimization failed!
# 'optimise_parameters': 4.737 seconds
# 'optimise_parameters': 4.738 seconds
# 'get_parameters': 0.011 seconds
# parameters:
# lengthscales: array([14.55773826,  8.07916985,  0.67949385])
# kernel_variance: 0.0018540519137867633
# likelihood_variance: 0.004186536062448457
# inducing_points: array([[  223.68206453,   274.33881219, 17896.        ],
#        [  233.10865294,   275.56819534, 17896.        ],
#        [  230.07488782,   278.17099254, 17896.        ],
#        [  236.52260119,   275.48906171, 17900.        ],
#        [  232.2238299 ,   269.86518739, 17890.        ]]) (truncated)
# 'predict': 0.191 seconds
# total run time : 8.28 seconds
# --------------------------------------------------
# 589 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 588  2.299052e+06  2.738319e+06  40.016321 -57.523658  17897.0         True
# 'local_data_select': 0.172 seconds
# number obs: 3924
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.068 seconds
# 'set_lengthscales_constraints': 0.018 seconds
# 'optimise_parameters': 3.739 seconds
# 'optimise_parameters': 3.739 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([1.0000000e-12, 5.8777361e+01, 1.0000000e-08])
# kernel_variance: 4.012739119412985
# likelihood_variance: 0.006187503771600037
# inducing_points: array([[  229.85365432,   282.91275479, 17892.        ],
#        [  232.29009372,   279.4922664 , 17896.        ],
#        [  235.51433183,   268.5427642 , 17904.        ],
#        [  229.35081945,   268.23202805, 17890.        ],
#        [  233.22900751,   267.27014227, 17904.        ]]) (truncated)
# 'predict': 0.169 seconds
# total run time : 6.82 seconds
# --------------------------------------------------
# 590 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 589  2.324052e+06  2.738319e+06  40.321762 -57.372815  17897.0         True
# 'local_data_select': 0.117 seconds
# number obs: 4456
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.053 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 3.908 seconds
# 'optimise_parameters': 3.909 seconds
# 'get_parameters': 0.016 seconds
# parameters:
# lengthscales: array([6.00000000e+01, 4.29155771e+00, 1.00000000e-08])
# kernel_variance: 0.0005780667204681277
# likelihood_variance: 0.004703557808749096
# inducing_points: array([[  236.42849478,   269.05087515, 17904.        ],
#        [  238.87202255,   276.83573662, 17900.        ],
#        [  234.25741202,   267.84325028, 17904.        ],
#        [  224.57746674,   268.5844826 , 17900.        ],
#        [  237.68541277,   272.95463811, 17890.        ]]) (truncated)
# 'predict': 0.279 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 8.17 seconds
# --------------------------------------------------
# 591 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 590  2.349052e+06  2.738319e+06  40.624463 -57.220965  17897.0         True
# 'local_data_select': 0.166 seconds
# number obs: 4949
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.075 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# **********
# optimization failed!
# 'optimise_parameters': 7.985 seconds
# 'optimise_parameters': 7.985 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([12.46661424,  9.58762119,  0.28566226])
# kernel_variance: 0.001615750057745895
# likelihood_variance: 0.004377633564847827
# inducing_points: array([[  241.29703367,   281.20194594, 17900.        ],
#        [  240.76049138,   272.13644318, 17890.        ],
#        [  237.03115094,   272.58559204, 17890.        ],
#        [  242.51563946,   276.49278409, 17890.        ],
#        [  229.86283684,   268.5234917 , 17890.        ]]) (truncated)
# 'predict': 0.183 seconds
# total run time : 11.23 seconds
# --------------------------------------------------
# 592 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 591  2.374052e+06  2.738319e+06  40.924445 -57.068117  17897.0         True
# 'local_data_select': 0.180 seconds
# number obs: 5060
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.066 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 8.344 seconds
# 'optimise_parameters': 8.345 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([22.22034385, 11.94416457,  8.99976755])
# kernel_variance: 0.00387450488144278
# likelihood_variance: 0.004272546757831018
# inducing_points: array([[  231.82922746,   266.48894518, 17904.        ],
#        [  243.97174481,   276.48600639, 17890.        ],
#        [  246.00434139,   277.64554547, 17904.        ],
#        [  232.67286589,   273.27435898, 17900.        ],
#        [  233.43101293,   276.42338735, 17896.        ]]) (truncated)
# 'predict': 0.177 seconds
# total run time : 11.47 seconds
# --------------------------------------------------
# 593 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 592  2.399052e+06  2.738319e+06  41.221729 -56.914282  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 5252
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.049 seconds
# 'set_lengthscales_constraints': 0.015 seconds
# 'optimise_parameters': 7.878 seconds
# 'optimise_parameters': 7.878 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([15.298805  , 11.14766538,  8.99982332])
# kernel_variance: 0.0027592400094171676
# likelihood_variance: 0.004127390559368758
# inducing_points: array([[  241.87704896,   282.68786359, 17900.        ],
#        [  234.23510253,   278.56113734, 17896.        ],
#        [  235.19219792,   274.72483607, 17900.        ],
#        [  249.66457951,   273.1203064 , 17894.        ],
#        [  232.53195561,   274.04086114, 17896.        ]]) (truncated)
# 'predict': 0.179 seconds
# total run time : 10.83 seconds
# --------------------------------------------------
# 594 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 593  2.424052e+06  2.738319e+06  41.516334 -56.759473  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 5027
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.052 seconds
# 'set_lengthscales_constraints': 0.016 seconds
# **********
# optimization failed!
# 'optimise_parameters': 6.062 seconds
# 'optimise_parameters': 6.062 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([11.71433128, 10.21816628,  0.32588504])
# kernel_variance: 0.0012984614594986248
# likelihood_variance: 0.004067479836073065
# inducing_points: array([[  243.94552894,   280.061276  , 17890.        ],
#        [  238.35368114,   266.20455775, 17890.        ],
#        [  234.14481692,   274.12233442, 17900.        ],
#        [  238.62485593,   266.87051331, 17890.        ],
#        [  240.26404432,   278.56319171, 17900.        ]]) (truncated)
# 'predict': 0.179 seconds
# total run time : 9.53 seconds
# --------------------------------------------------
# 595 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 594  2.449052e+06  2.738319e+06  41.808281 -56.603699  17897.0         True
# 'local_data_select': 0.175 seconds
# number obs: 5258
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.066 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 4.863 seconds
# 'optimise_parameters': 4.864 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([14.25421395, 11.81348321,  0.97013357])
# kernel_variance: 0.001580947341168505
# likelihood_variance: 0.003915247116472509
# inducing_points: array([[  238.84454665,   274.95291452, 17900.        ],
#        [  247.97134794,   272.20901258, 17894.        ],
#        [  244.25618898,   276.64517207, 17890.        ],
#        [  249.00450899,   272.76528226, 17894.        ],
#        [  247.69638577,   274.17561591, 17894.        ]]) (truncated)
# 'predict': 0.178 seconds
# total run time : 7.94 seconds
# --------------------------------------------------
# 596 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 595  2.474052e+06  2.738319e+06  42.097592 -56.446971  17897.0         True
# 'local_data_select': 0.115 seconds
# number obs: 5191
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.051 seconds
# 'set_lengthscales_constraints': 0.025 seconds
# **********
# optimization failed!
# 'optimise_parameters': 8.188 seconds
# 'optimise_parameters': 8.189 seconds
# 'get_parameters': 0.016 seconds
# parameters:
# lengthscales: array([15.04402223, 10.29949687,  0.96164609])
# kernel_variance: 0.0013825308013153202
# likelihood_variance: 0.003901761360651335
# inducing_points: array([[  238.59325592,   274.31568401, 17900.        ],
#        [  239.15509518,   276.99773686, 17900.        ],
#        [  239.67016285,   269.44324555, 17890.        ],
#        [  253.39593777,   268.65548336, 17898.        ],
#        [  246.97722263,   280.02545416, 17904.        ]]) (truncated)
# 'predict': 0.237 seconds
# total run time : 11.27 seconds
# --------------------------------------------------
# 597 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 596  2.499052e+06  2.738319e+06  42.384286 -56.289299  17897.0         True
# 'local_data_select': 0.112 seconds
# number obs: 4892
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.048 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# **********
# optimization failed!
# 'optimise_parameters': 6.768 seconds
# 'optimise_parameters': 6.769 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([24.44948306,  9.26566336,  0.27296795])
# kernel_variance: 0.0014832220945638671
# likelihood_variance: 0.0039019825066760124
# inducing_points: array([[  240.21704127,   274.37995546, 17890.        ],
#        [  257.67956055,   270.86526619, 17898.        ],
#        [  243.08969357,   279.2439154 , 17900.        ],
#        [  251.38651078,   268.37638589, 17898.        ],
#        [  247.28256733,   271.83777692, 17894.        ]]) (truncated)
# 'predict': 0.173 seconds
# total run time : 10.26 seconds
# --------------------------------------------------
# 598 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 597  2.524052e+06  2.738319e+06  42.668386 -56.130694  17897.0         True
# 'local_data_select': 0.175 seconds
# number obs: 4426
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.070 seconds
# 'set_lengthscales_constraints': 0.014 seconds
# 'optimise_parameters': 5.815 seconds
# 'optimise_parameters': 5.815 seconds
# 'get_parameters': 0.008 seconds
# parameters:
# lengthscales: array([19.20619428,  7.78080173,  8.99959737])
# kernel_variance: 0.0016317304450499802
# likelihood_variance: 0.003843466673572138
# inducing_points: array([[  247.69790104,   278.56675792, 17890.        ],
#        [  243.48897511,   271.52793595, 17904.        ],
#        [  260.13786562,   278.71567959, 17894.        ],
#        [  251.3557802 ,   282.94418054, 17894.        ],
#        [  249.7277605 ,   264.61691897, 17898.        ]]) (truncated)
# 'predict': 0.180 seconds
# total run time : 8.87 seconds
# --------------------------------------------------
# 599 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 598  2.549052e+06  2.738319e+06  42.949913 -55.971166  17897.0         True
# 'local_data_select': 0.118 seconds
# number obs: 4017
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.042 seconds
# 'set_lengthscales_constraints': 0.009 seconds
# 'optimise_parameters': 5.357 seconds
# 'optimise_parameters': 5.358 seconds
# 'get_parameters': 0.013 seconds
# parameters:
# lengthscales: array([21.80656255,  8.15422196,  7.45845262])
# kernel_variance: 0.002078662879418481
# likelihood_variance: 0.0037816080311561936
# inducing_points: array([[  252.90953594,   278.11709658, 17904.        ],
#        [  254.11955108,   269.02958646, 17898.        ],
#        [  257.36457481,   280.53714661, 17904.        ],
#        [  258.33548651,   281.06283165, 17904.        ],
#        [  254.33747271,   278.89419982, 17904.        ]]) (truncated)
# 'predict': 0.229 seconds
# total run time : 8.82 seconds
# --------------------------------------------------
# 600 / 600
# current local expert:
#                 x             y        lon        lat        t  is_in_ocean
# 599  2.574052e+06  2.738319e+06  43.228888 -55.810725  17897.0         True
# 'local_data_select': 0.113 seconds
# number obs: 3533
# setting lengthscales to: [1. 1. 1.]
# '__init__': 0.043 seconds
# 'set_lengthscales_constraints': 0.012 seconds
# 'optimise_parameters': 3.896 seconds
# 'optimise_parameters': 3.896 seconds
# 'get_parameters': 0.009 seconds
# parameters:
# lengthscales: array([14.54273386,  9.94143301,  4.86674831])
# kernel_variance: 0.001686429369597059
# likelihood_variance: 0.0038025617269621713
# inducing_points: array([[  251.93851141,   277.58789181, 17904.        ],
#        [  248.65401527,   275.79324344, 17904.        ],
#        [  261.14347566,   266.15676232, 17902.        ],
#        [  259.59690981,   265.39104755, 17902.        ],
#        [  257.69410764,   268.55085091, 17902.        ]]) (truncated)
# 'predict': 0.164 seconds
# SAVING RESULTS TO TABLES:
# run_details
# preds
# lengthscales
# kernel_variance
# likelihood_variance
# inducing_points
# total run time : 7.47 seconds
# 'run': 4631.935 seconds

# %% [markdown]
# ### Glue initial results

# %%
# extract, store in dict
dfs, _ = get_results_from_h5file(store_path)

print(f"tables in results file: {list(dfs.keys())}")
# Out:
# reading in results
# getting all tables
# merging on expert location data
# table: 'oi_config' does not have all coords_col: ['x', 'y', 't'] in columns, not merging on expert_locations
# tables in results file: ['expert_locs', 'inducing_points', 'kernel_variance', 'lengthscales', 'likelihood_variance', 'oi_config', 'preds', 'run_details']

# %%
preds_data = dfs["preds"]
preds_data.head()
inference_radius = 50_000
# multiple local experts may make predictions at the same prediction location (pred_loc).
# - for each prediction at a given location, take we weighted combination
# - weights being a function of the distance to each local expert that made a prediction at a given location.
plt_data = glue_local_predictions_2d(preds_df=preds_data,
                                     pred_loc_cols=["pred_loc_x", "pred_loc_y"],
                                     xprt_loc_cols=["x", "y"],
                                     vars_to_glue=["f*", "f*_var"],
                                     inference_radius=inference_radius)
plt_data['lon'],plt_data['lat'] = EASE2toWGS84_New(plt_data['pred_loc_x'],plt_data['pred_loc_y'],lat_0=-90)
#Set to nan predictions that are not over the ocean
plt_data['is_ocean'] = globe.is_ocean(plt_data['lat'], plt_data['lon'])
plt_data.loc[plt_data['is_ocean'] == False, 'f*'] = np.nan
plt_data.head()
# Out:
# /tmp/ipykernel_99806/2856331274.py:12: DeprecationWarning: Call to deprecated function (or staticmethod) EASE2toWGS84_New. (This function will be removed in future versions. Use `EASE2toWGS84` instead.)
#   plt_data['lon'],plt_data['lat'] = EASE2toWGS84_New(plt_data['pred_loc_x'],plt_data['pred_loc_y'],lat_0=-90)
#      pred_loc_x    pred_loc_y        f*    f*_var        lon        lat  \
# 0  2.004052e+06  2.143319e+06  0.040016  0.000191  43.076754 -63.475012
# 1  2.004052e+06  2.148319e+06  0.040286  0.000185  43.010157 -63.441331
# 2  2.004052e+06  2.153319e+06  0.040713  0.000177  42.943726 -63.407611
# 3  2.004052e+06  2.158319e+06  0.041239  0.000169  42.877459 -63.373852
# 4  2.004052e+06  2.163319e+06  0.041856  0.000157  42.811357 -63.340054
#
#    is_ocean
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %% [markdown]
# ## Visualise OI results

# %%
fig, ax = plt.subplots()
sla_preds = ax.scatter(plt_data['pred_loc_x'],plt_data['pred_loc_y'],c=plt_data['f*'],s=10,cmap='seismic',vmin=-0.2,vmax=0.2)
fig.colorbar(sla_preds, ax=ax, label='SSHA (m)', pad=0.01)
ax.set_title('GPSat predictions')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
# @title
fig,axs = plt.subplots(2,3,figsize=(10,10),subplot_kw=dict(projection=ccrs.SouthPolarStereo()))
axs = axs.flatten()
eddy_proxy = mlines.Line2D([], [], color='black', linestyle='--', linewidth=1, alpha=0.9, label="Selected AVISO eddy")

for i, ax in enumerate(axs):
    if i == 2:
        continue # We will leave ax[2] empty
    ax.set_extent([0, 90, -90, -60], crs=ccrs.PlateCarree())
    ax.coastlines()
    ax.add_feature(cfeature.LAND, color='lightgray')
    ax.add_geometries(
    selected_eddy['geometry'], crs=ccrs.PlateCarree(),
    facecolor="none", edgecolor="black", linewidth=1, linestyle='--', alpha=0.9, zorder=100)


axs[0].scatter(sral_ds.where(sral_ds.time_20_ku.dt.date == selected_eddy['time'].values[0].astype("datetime64[D]"))['lon_20_ku'],\
               sral_ds.where(sral_ds.time_20_ku.dt.date == selected_eddy['time'].values[0].astype("datetime64[D]"))['lat_20_ku'],\
               c=sral_ds.where(sral_ds.time_20_ku.dt.date == selected_eddy['time'].values[0].astype("datetime64[D]"))['ssha_20_ku'],\
               s=1, cmap='seismic', vmin=-0.2, vmax=0.2, transform=ccrs.PlateCarree())
axs[0].set_title(f'SSHA Along-track observations\n{selected_eddy["time"].values[0].astype("datetime64[D]")}')
axs[0].legend(handles=[eddy_proxy], loc='lower left', fontsize=10)

axs[1].scatter(gridded_obvs_df[gridded_obvs_df['t'] == selected_eddy['time'].values[0].astype("datetime64[D]").astype(float)]['x'],\
                gridded_obvs_df[gridded_obvs_df['t'] == selected_eddy['time'].values[0].astype("datetime64[D]").astype(float)]['y'],\
                c=gridded_obvs_df[gridded_obvs_df['t'] == selected_eddy['time'].values[0].astype("datetime64[D]").astype(float)]['ssha_20_ku'],\
                s=1, cmap='seismic', vmin=-0.2, vmax=0.2, transform=ccrs.epsg(6932))
axs[1].set_title(f'SSHA Binned observations:\n{selected_eddy["time"].values[0].astype("datetime64[D]")}')

axs[2].axis('off')

axs[3].scatter(sral_df['lon_20_ku'],sral_df['lat_20_ku'],c=sral_df['ssha_20_ku'],s=1,cmap='seismic',vmin=-0.2,vmax=0.2,transform=ccrs.PlateCarree())
axs[3].set_title(f'Along-track observations\n± {training_window.days} days (stacked)')

axs[4].scatter(gridded_obvs_df['x'],gridded_obvs_df['y'],c=gridded_obvs_df['ssha_20_ku'],s=1,cmap='seismic',vmin=-0.2,vmax=0.2, transform=ccrs.epsg(6932))
axs[4].set_title(f'Binned observations\n± {training_window.days} days (stacked)')

axs[5].scatter(plt_data['lon'],plt_data['lat'],c=plt_data['f*'],s=1,cmap='seismic',vmin=-0.2,vmax=0.2,transform=ccrs.PlateCarree())
axs[5].set_title(f'OI predictions {selected_eddy["time"].values[0].astype("datetime64[D]")}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Qualitatively, we have been able to construct an SSH field using optimal interpolation that appears to capture well the known eddy in terms of its position and height. This is despite not having a single direct overpass on the date of interest.
#
# The next step would be to process this SSH field to extract the eddy bounds and more of its characteristics (vorticity, inner height vs effective height, etc). See literature such as: Mason, E., A. Pascual, and J. C. McWilliams, 2014: A New Sea Surface Height–Based Code for Oceanic Mesoscale Eddy Tracking. J. Atmos. Oceanic Technol., 31, 1181–1188, https://doi.org/10.1175/JTECH-D-14-00019.1 and its associated python package, https://py-eddy-tracker.readthedocs.io/en/latest/python_module/index.html, for the steps taken to do achieve this.
